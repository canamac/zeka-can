# %% [markdown]
# <a href="https://colab.research.google.com/github/canamac/zeka-can/blob/main/999_Chandelier_Exit_G%C3%BCnl%C3%BCk.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
if os.path.exists('StockIndicators.py'):
      os.remove('StockIndicators.py')

# !pip install git+https://github.com/rongardF/tvdatafeed tradingview-screener
# !wget https://raw.githubusercontent.com/Onuragdaci/Stock_Indicators/main/StockIndicators.py

import pandas as pd
import StockIndicators as SI

"""exchange Kripto için 'BIST' yerine 'BINANCE' yazın"""

"""Diğer zaman periyotları için
#Dakikalık                  : 1m, 3m, 5m, 30m, 45m
#Saatlik                    : 1h, 2h, 3h, 4h
#Günlük / Haftalık / Aylık  : 1D, 1W, 1M  """

exchange = 'BIST'
periyot = '1D'

datas = SI.Stocks(exchange)
print(datas)

Titles = ['Hisse Adı', 'Son Fiyat','Giriş Sinyali', 'Çıkış Sinyali']
df_signals = pd.DataFrame(columns=Titles)

for i in range(0,len(datas)):
    try:
        data = SI.TVGet(datas[i],exchange,periyot,100)
        data = SI.chandelier_exit(data)

        Buy = False
        Sell = False
        Signals = data.tail(2)
        Signals = Signals.reset_index()
        Buy = Signals.loc[0, 'Entry'] == False and Signals.loc[1, 'Entry'] == True
        Sell = Signals.loc[0, 'Exit'] == False and Signals.loc[1, 'Exit'] == True
        Last_Price = Signals.loc[1, 'close']
        L1 = [datas[i] ,Last_Price,str(Buy),str(Sell)]
        df_signals.loc[len(df_signals)] = L1
        print(L1)
    except:
        pass

df_True = df_signals[(df_signals['Giriş Sinyali'] == 'True')]
print(df_True.to_string())
# Out:
# Collecting git+https://github.com/rongardF/tvdatafeed
#   Cloning https://github.com/rongardF/tvdatafeed to /tmp/pip-req-build-s64nvz93
#   Running command git clone --filter=blob:none --quiet https://github.com/rongardF/tvdatafeed /tmp/pip-req-build-s64nvz93
#   Resolved https://github.com/rongardF/tvdatafeed to commit e6f6aaa7de439ac6e454d9b26d2760ded8dc4923
#   Preparing metadata (setup.py) ... done
# Collecting tradingview-screener
#   Downloading tradingview_screener-2.5.0-py3-none-any.whl (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.5/43.5 kB 346.7 kB/s eta 0:00:00
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tvdatafeed==2.1.0) (67.7.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from tvdatafeed==2.1.0) (2.0.3)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from tvdatafeed==2.1.0) (1.8.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from tvdatafeed==2.1.0) (2.31.0)
# Collecting pandas (from tvdatafeed==2.1.0)
#   Downloading pandas-2.2.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 17.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas->tvdatafeed==2.1.0) (1.25.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->tvdatafeed==2.1.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->tvdatafeed==2.1.0) (2023.4)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->tvdatafeed==2.1.0) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->tvdatafeed==2.1.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->tvdatafeed==2.1.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->tvdatafeed==2.1.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->tvdatafeed==2.1.0) (2024.6.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->tvdatafeed==2.1.0) (1.16.0)
# Building wheels for collected packages: tvdatafeed
#   Building wheel for tvdatafeed (setup.py) ... done
#   Created wheel for tvdatafeed: filename=tvdatafeed-2.1.0-py3-none-any.whl size=17533 sha256=a149ce1e804c058c5657c1ab2377e9335ea1ec69dc04570c27c839590e5b4633
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ji86b62b/wheels/e4/32/1e/21ebcacc6549d75fae3bf3ff75cee8fcbe4e5c189d88fbd5a1
# Successfully built tvdatafeed
# Installing collected packages: pandas, tvdatafeed, tradingview-screener
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.0.3
#     Uninstalling pandas-2.0.3:
#       Successfully uninstalled pandas-2.0.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.4.1 requires pandas<2.2.2dev0,>=2.0, but you have pandas 2.2.2 which is incompatible.
# google-colab 1.0.0 requires pandas==2.0.3, but you have pandas 2.2.2 which is incompatible.
# Successfully installed pandas-2.2.2 tradingview-screener-2.5.0 tvdatafeed-2.1.0
# --2024-06-26 23:26:08--  https://raw.githubusercontent.com/Onuragdaci/Stock_Indicators/main/StockIndicators.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 58058 (57K) [text/plain]
# Saving to: ‘StockIndicators.py’
#
# StockIndicators.py  100%[===================>]  56.70K  --.-KB/s    in 0.01s
#
# 2024-06-26 23:26:08 (4.45 MB/s) - ‘StockIndicators.py’ saved [58058/58058]
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# ['A1CAP', 'ACSEL', 'ADEL', 'ADESE', 'ADGYO', 'AEFES', 'AFYON', 'AGESA', 'AGHOL', 'AGROT', 'AGYO', 'AHGAZ', 'AKBNK', 'AKCNS', 'AKENR', 'AKFGY', 'AKFYE', 'AKGRT', 'AKMGY', 'AKSA', 'AKSEN', 'AKSGY', 'AKSUE', 'AKYHO', 'ALARK', 'ALBRK', 'ALBTS', 'ALCAR', 'ALCTL', 'ALDUK', 'ALFAS', 'ALGYO', 'ALKA', 'ALKIM', 'ALKLC', 'ALMAD', 'ALTIN', 'ALTNY', 'ALVES', 'ANELE', 'ANGEN', 'ANHYT', 'ANSGR', 'APBDL', 'APLIB', 'APX30', 'APYKF', 'APYKS', 'APYMD', 'ARASE', 'ARCLK', 'ARDYZ', 'ARENA', 'ARSAN', 'ARTMS', 'ARZUM', 'ASELS', 'ASGYO', 'ASTOR', 'ASUZU', 'ATAGY', 'ATAKP', 'ATATP', 'ATEKS', 'ATLAS', 'ATSYH', 'AVGYO', 'AVHOL', 'AVOD', 'AVPGY', 'AVTUR', 'AYCES', 'AYDEM', 'AYEN', 'AYES', 'AYGAZ', 'AZTEK', 'BAGFS', 'BAKAB', 'BALAT', 'BANVT', 'BARMA', 'BASCM', 'BASGZ', 'BAYRK', 'BEGYO', 'BERA', 'BEYAZ', 'BFREN', 'BIENY', 'BIGCH', 'BIMAS', 'BINHO', 'BIOEN', 'BIZIM', 'BJKAS', 'BLCYT', 'BMSCH', 'BMSTL', 'BNTAS', 'BOBET', 'BORLS', 'BORSK', 'BOSSA', 'BRISA', 'BRKO', 'BRKSN', 'BRKVY', 'BRLSM', 'BRMEN', 'BRSAN', 'BRYAT', 'BSOKE', 'BTCIM', 'BUCIM', 'BURCE', 'BURVA', 'BVSAN', 'BYDNR', 'CANTE', 'CASA', 'CATES', 'CCOLA', 'CELHA', 'CEMAS', 'CEMTS', 'CEOEM', 'CIMSA', 'CLEBI', 'CMBTN', 'CMENT', 'CONSE', 'COSMO', 'CRDFA', 'CRFSA', 'CUSAN', 'CVKMD', 'CWENE', 'DAGHL', 'DAGI', 'DAPGM', 'DARDL', 'DENGE', 'DERHL', 'DERIM', 'DESA', 'DESPC', 'DEVA', 'DGATE', 'DGGYO', 'DGNMO', 'DIRIT', 'DITAS', 'DMRGD', 'DMSAS', 'DNISI', 'DOAS', 'DOBUR', 'DOCO', 'DOFER', 'DOGUB', 'DOHOL', 'DOKTA', 'DURDO', 'DYOBY', 'DZGYO', 'EBEBK', 'ECILC', 'ECZYT', 'EDATA', 'EDIP', 'EGEEN', 'EGEPO', 'EGGUB', 'EGPRO', 'EGSER', 'EKGYO', 'EKIZ', 'EKOS', 'EKSUN', 'ELITE', 'EMKEL', 'EMNIS', 'ENERY', 'ENJSA', 'ENKAI', 'ENSRI', 'ENTRA', 'EPLAS', 'ERBOS', 'ERCB', 'EREGL', 'ERSU', 'ESCAR', 'ESCOM', 'ESEN', 'ETILR', 'ETYAT', 'EUHOL', 'EUKYO', 'EUPWR', 'EUREN', 'EUYO', 'EYGYO', 'FADE', 'FENER', 'FLAP', 'FMIZP', 'FONET', 'FORMT', 'FORTE', 'FRIGO', 'FROTO', 'FZLGY', 'GARAN', 'GARFA', 'GEDIK', 'GEDZA', 'GENIL', 'GENTS', 'GEREL', 'GESAN', 'GIPTA', 'GLBMD', 'GLCVY', 'GLDTR', 'GLRYH', 'GLYHO', 'GMSTR', 'GMTAS', 'GOKNR', 'GOLTS', 'GOODY', 'GOZDE', 'GRNYO', 'GRSEL', 'GRTRK', 'GSDDE', 'GSDHO', 'GSRAY', 'GUBRF', 'GWIND', 'GZNMI', 'HALKB', 'HATEK', 'HATSN', 'HDFGS', 'HEDEF', 'HEKTS', 'HKTM', 'HLGYO', 'HOROZ', 'HRKET', 'HTTBT', 'HUBVC', 'HUNER', 'HURGZ', 'ICBCT', 'ICUGS', 'IDGYO', 'IEYHO', 'IHAAS', 'IHEVA', 'IHGZT', 'IHLAS', 'IHLGM', 'IHYAY', 'IMASM', 'INDES', 'INFO', 'INGRM', 'INTEM', 'INVEO', 'INVES', 'IPEKE', 'ISATR', 'ISBIR', 'ISBTR', 'ISCTR', 'ISDMR', 'ISFIN', 'ISGSY', 'ISGYO', 'ISKPL', 'ISKUR', 'ISMEN', 'ISSEN', 'ISYAT', 'IZENR', 'IZFAS', 'IZINV', 'IZMDC', 'JANTS', 'KAPLM', 'KAREL', 'KARSN', 'KARTN', 'KARYE', 'KATMR', 'KAYSE', 'KBORU', 'KCAER', 'KCHOL', 'KENT', 'KERVN', 'KERVT', 'KFEIN', 'KGYO', 'KIMMR', 'KLGYO', 'KLKIM', 'KLMSN', 'KLNMA', 'KLRHO', 'KLSER', 'KLSYN', 'KMPUR', 'KNFRT', 'KOCMT', 'KONKA', 'KONTR', 'KONYA', 'KOPOL', 'KORDS', 'KOTON', 'KOZAA', 'KOZAL', 'KRDMA', 'KRDMB', 'KRDMD', 'KRGYO', 'KRONT', 'KRPLS', 'KRSTL', 'KRTEK', 'KRVGD', 'KSTUR', 'KTLEV', 'KTSKR', 'KUTPO', 'KUVVA', 'KUYAS', 'KZBGY', 'KZGYO', 'LIDER', 'LIDFA', 'LILAK', 'LINK', 'LKMNH', 'LMKDC', 'LOGO', 'LRSHO', 'LUKSK', 'MAALT', 'MACKO', 'MAGEN', 'MAKIM', 'MAKTK', 'MANAS', 'MARBL', 'MARKA', 'MARTI', 'MAVI', 'MEDTR', 'MEGAP', 'MEGMT', 'MEKAG', 'MEPET', 'MERCN', 'MERIT', 'MERKO', 'METRO', 'METUR', 'MGROS', 'MHRGY', 'MIATK', 'MIPAZ', 'MMCAS', 'MNDRS', 'MNDTR', 'MOBTL', 'MOGAN', 'MPARK', 'MPATA', 'MRGYO', 'MRSHL', 'MSGYO', 'MTRKS', 'MTRYO', 'MZHLD', 'NATEN', 'NETAS', 'NIBAS', 'NTGAZ', 'NTHOL', 'NUGYO', 'NUHCM', 'OBAMS', 'OBASE', 'ODAS', 'ODINE', 'OFSYM', 'ONCSM', 'ONRYT', 'OPX30', 'ORCAY', 'ORGE', 'ORMA', 'OSMEN', 'OSTIM', 'OTKAR', 'OTTO', 'OYAKC', 'OYAYO', 'OYLUM', 'OYYAT', 'OZGYO', 'OZKGY', 'OZRDN', 'OZSUB', 'OZYSR', 'PAGYO', 'PAMEL', 'PAPIL', 'PARSN', 'PASEU', 'PATEK', 'PCILT', 'PEHOL', 'PEKGY', 'PENGD', 'PENTA', 'PETKM', 'PETUN', 'PGSUS', 'PINSU', 'PKART', 'PKENT', 'PLTUR', 'PNLSN', 'PNSUT', 'POLHO', 'POLTK', 'PRDGS', 'PRKAB', 'PRKME', 'PRZMA', 'PSDTC', 'P ...
# ['A1CAP', 26.58, 'False', 'False']
# ['ACSEL', 132.2, 'False', 'False']
# ['ADEL', 496.5, 'False', 'False']
# ['ADESE', 2.14, 'False', 'False']
# ['ADGYO', 28.700001, 'False', 'False']
# ['AEFES', 230.7, 'False', 'False']
# ['AFYON', 12.15, 'False', 'False']
# ['AGESA', 125.1, 'False', 'False']
# ['AGHOL', 343.5, 'False', 'False']
# ['AGROT', 15.03, 'False', 'False']
# ['AGYO', 7.8, 'False', 'False']
# ['AHGAZ', 14.66, 'False', 'False']
# ['AKBNK', 64.800003, 'False', 'False']
# ['AKCNS', 139.3, 'False', 'False']
# ['AKENR', 16.120001, 'False', 'False']
# ['AKFGY', 2.26, 'False', 'False']
# ['AKFYE', 28.799999, 'False', 'False']
# ['AKGRT', 8.08, 'False', 'False']
# ['AKMGY', 257.5, 'False', 'False']
# ['AKSA', 133.3, 'False', 'False']
# ['AKSEN', 44.299999, 'False', 'False']
# ['AKSGY', 19.0, 'False', 'False']
# ['AKSUE', 11.76, 'False', 'False']
# ['AKYHO', 8.22, 'False', 'False']
# ['ALARK', 102.0, 'False', 'False']
# ['ALBRK', 5.51, 'False', 'False']
# ['ALBTS', 2662.0, 'False', 'False']
# ['ALCAR', 1440.0, 'False', 'False']
# ['ALCTL', 100.1, 'False', 'False']
# ['ALDUK', 6950.0, 'False', 'False']
# ['ALFAS', 67.900002, 'False', 'False']
# ['ALGYO', 42.540001, 'False', 'False']
# ['ALKA', 27.379999, 'False', 'False']
# ['ALKIM', 33.5, 'False', 'False']
# ['ALMAD', 6.39, 'False', 'False']
# ['ALTIN', 24.26, 'False', 'False']
# ['ALTNY', 83.800003, 'False', 'False']
# ['ALVES', 42.139999, 'False', 'False']
# ['ANELE', 16.620001, 'False', 'False']
# ['ANGEN', 11.57, 'False', 'False']
# ['ANHYT', 128.89999, 'False', 'False']
# ['ANSGR', 105.5, 'False', 'False']
# ['APBDL', 23.42, 'False', 'False']
# ['APLIB', 40.950001, 'False', 'False']
# ['APX30', 27.66, 'False', 'False']
# ['APYKF', 1750.0, 'False', 'False']
# ['APYKS', 1497.5, 'False', 'False']
# ['APYMD', 3427.0, 'False', 'False']
# ['ARASE', 58.150002, 'False', 'False']
# ['ARCLK', 175.0, 'False', 'False']
# ['ARDYZ', 37.240002, 'False', 'False']
# ['ARENA', 39.599998, 'False', 'False']
# ['ARSAN', 16.469999, 'False', 'False']
# ['ARTMS', 42.200001, 'False', 'False']
# ['ARZUM', 66.449997, 'False', 'False']
# ['ASELS', 58.900002, 'False', 'False']
# ['ASGYO', 13.02, 'False', 'False']
# ['ASTOR', 95.800003, 'False', 'False']
# ['ASUZU', 90.0, 'False', 'False']
# ['ATAGY', 13.2, 'False', 'False']
# ['ATAKP', 47.959999, 'False', 'False']
# ['ATATP', 137.7, 'False', 'False']
# ['ATEKS', 154.0, 'False', 'False']
# ['ATLAS', 4.67, 'False', 'False']
# ['ATSYH', 46.5, 'False', 'False']
# ['AVGYO', 7.3, 'False', 'False']
# ['AVHOL', 32.5, 'False', 'False']
# ['AVOD', 3.37, 'False', 'False']
# ['AVPGY', 41.0, 'False', 'False']
# ['AVTUR', 13.95, 'False', 'False']
# ['AYCES', 672.5, 'False', 'False']
# ['AYDEM', 34.880001, 'False', 'False']
# ['AYEN', 31.219999, 'False', 'False']
# ['AYES', 45.900002, 'False', 'False']
# ['AYGAZ', 172.3, 'False', 'False']
# ['AZTEK', 60.0, 'False', 'False']
# ['BAGFS', 22.059999, 'False', 'False']
# ['BAKAB', 40.119999, 'False', 'False']
# ['BALAT', 38.720001, 'False', 'False']
# ['BANVT', 353.0, 'False', 'False']
# ['BARMA', 17.700001, 'False', 'False']
# ['BASCM', 13.12, 'False', 'False']
# ['BASGZ', 31.9, 'False', 'False']
# ['BAYRK', 53.5, 'False', 'False']
# ['BEGYO', 3.21, 'False', 'False']
# ['BERA', 18.530001, 'False', 'False']
# ['BEYAZ', 21.76, 'False', 'False']
# ['BFREN', 850.0, 'False', 'False']
# ['BIENY', 32.82, 'False', 'False']
# ['BIGCH', 30.32, 'False', 'False']
# ['BIMAS', 559.5, 'False', 'False']
# ['BINHO', 377.0, 'False', 'False']
# ['BIOEN', 20.559999, 'False', 'False']
# ['BIZIM', 34.279999, 'False', 'False']
# ['BJKAS', 32.919998, 'False', 'False']
# ['BLCYT', 16.5, 'False', 'False']
# ['BMSCH', 24.18, 'False', 'False']
# ['BMSTL', 43.900002, 'False', 'False']
# ['BNTAS', 11.88, 'False', 'False']
# ['BOBET', 27.219999, 'False', 'False']
# ['BORLS', 35.139999, 'False', 'False']
# ['BORSK', 29.200001, 'False', 'False']
# ['BOSSA', 16.1, 'False', 'False']
# ['BRISA', 110.2, 'False', 'False']
# ['BRKO', 9.6, 'False', 'False']
# ['BRKSN', 33.82, 'False', 'False']
# ['BRKVY', 57.75, 'False', 'False']
# ['BRLSM', 17.99, 'False', 'False']
# ['BRMEN', 5.04, 'False', 'False']
# ['BRSAN', 457.0, 'False', 'False']
# ['BRYAT', 2265.0, 'False', 'False']
# ['BSOKE', 30.799999, 'False', 'False']
# ['BTCIM', 161.3, 'False', 'False']
# ['BUCIM', 8.15, 'False', 'False']
# ['BURCE', 243.7, 'False', 'False']
# ['BURVA', 126.5, 'False', 'False']
# ['BVSAN', 99.0, 'False', 'False']
# ['BYDNR', 26.9, 'False', 'False']
# ['CANTE', 2.0, 'False', 'False']
# ['CASA', 100.0, 'False', 'False']
# ['CATES', 50.799999, 'False', 'False']
# ['CCOLA', 767.5, 'False', 'False']
# ['CELHA', 22.74, 'False', 'False']
# ['CEMAS', 3.67, 'False', 'True']
# ['CEMTS', 12.19, 'False', 'False']
# ['CEOEM', 22.540001, 'False', 'False']
# ['CIMSA', 29.66, 'False', 'False']
# ['CLEBI', 2489.0, 'False', 'False']
# ['CMBTN', 2985.0, 'False', 'False']
# ['CMENT', 368.25, 'False', 'False']
# ['CONSE', 5.28, 'False', 'False']
# ['COSMO', 120.4, 'False', 'False']
# ['CRDFA', 8.61, 'False', 'False']
# ['CRFSA', 111.5, 'False', 'False']
# ['CUSAN', 22.379999, 'False', 'False']
# ['CVKMD', 435.5, 'False', 'False']
# ['CWENE', 208.39999, 'False', 'True']
# ['DAGHL', 16.6, 'False', 'False']
# ['DAGI', 8.36, 'False', 'False']
# ['DAPGM', 34.439999, 'False', 'False']
# ['DARDL', 6.06, 'False', 'False']
# ['DENGE', 4.23, 'False', 'False']
# ['DERHL', 7.85, 'False', 'False']
# ['DERIM', 39.919998, 'False', 'False']
# ['DESA', 29.879999, 'False', 'False']
# ['DESPC', 38.419998, 'False', 'False']
# ['DEVA', 80.0, 'False', 'False']
# ['DGATE', 34.400002, 'False', 'False']
# ['DGGYO', 31.68, 'False', 'False']
# ['DGNMO', 11.4, 'False', 'False']
# ['DIRIT', 23.24, 'False', 'False']
# ['DITAS', 15.65, 'False', 'False']
# ['DMRGD', 13.36, 'False', 'False']
# ['DMSAS', 6.1, 'False', 'False']
# ['DNISI', 14.75, 'False', 'False']
# ['DOAS', 269.0, 'False', 'False']
# ['DOBUR', 206.60001, 'False', 'False']
# ['DOCO', 5752.5, 'False', 'False']
# ['DOFER', 38.240002, 'False', 'False']
# ['DOGUB', 30.84, 'False', 'False']
# ['DOHOL', 16.58, 'False', 'False']
# ['DOKTA', 31.719999, 'False', 'False']
# ['DURDO', 13.85, 'False', 'False']
# ['DYOBY', 52.849998, 'False', 'False']
# ['DZGYO', 4.62, 'False', 'False']
# ['EBEBK', 45.68, 'False', 'False']
# ['ECILC', 51.0, 'False', 'False']
# ['ECZYT', 226.3, 'False', 'False']
# ['EDATA', 16.07, 'False', 'False']
# ['EDIP', 24.0, 'False', 'False']
# ['EGEEN', 12270.0, 'False', 'False']
# ['EGEPO', 18.4, 'False', 'False']
# ['EGGUB', 38.439999, 'False', 'False']
# ['EGPRO', 201.10001, 'False', 'False']
# ['EGSER', 3.39, 'False', 'False']
# ['EKGYO', 9.6, 'True', 'False']
# ['EKIZ', 75.0, 'False', 'False']
# ['EKOS', 31.58, 'False', 'False']
# ['EKSUN', 55.849998, 'False', 'False']
# ['ELITE', 28.02, 'False', 'False']
# ['EMKEL', 12.03, 'False', 'False']
# ['EMNIS', 374.75, 'False', 'False']
# ['ENERY', 192.89999, 'False', 'False']
# ['ENJSA', 64.199997, 'False', 'False']
# ['ENKAI', 41.439999, 'False', 'False']
# ['ENSRI', 17.809999, 'False', 'False']
# ['ENTRA', 10.09, 'False', 'False']
# ['EPLAS', 7.52, 'False', 'False']
# ['ERBOS', 205.0, 'False', 'False']
# ['ERCB', 117.2, 'False', 'False']
# ['EREGL', 52.049999, 'False', 'False']
# ['ERSU', 19.6, 'False', 'False']
# ['ESCAR', 343.0, 'False', 'False']
# ['ESCOM', 58.0, 'False', 'False']
# ['ESEN', 20.639999, 'False', 'False']
# ['ETILR', 24.74, 'False', 'False']
# ['ETYAT', 13.71, 'False', 'False']
# ['EUHOL', 2.85, 'False', 'False']
# ['EUKYO', 25.24, 'False', 'False']
# ['EUPWR', 102.1, 'False', 'False']
# ['EUREN', 14.36, 'False', 'False']
# ['EUYO', 13.4, 'False', 'False']
# ['EYGYO', 10.33, 'False', 'False']
# ['FADE', 16.6, 'False', 'False']
# ['FENER', 175.5, 'False', 'False']
# ['FLAP', 7.55, 'False', 'False']
# ['FMIZP', 313.5, 'False', 'False']
# ['FONET', 17.25, 'False', 'False']
# ['FORMT', 3.07, 'False', 'False']
# ['FORTE', 52.049999, 'False', 'False']
# ['FRIGO', 7.66, 'False', 'False']
# ['FROTO', 1102.0, 'False', 'False']
# ['FZLGY', 12.03, 'False', 'False']
# ['GARAN', 113.0, 'False', 'False']
# ['GARFA', 23.639999, 'False', 'False']
# ['GEDIK', 14.68, 'False', 'False']
# ['GEDZA', 24.059999, 'False', 'False']
# ['GENIL', 66.449997, 'False', 'False']
# ['GENTS', 8.73, 'False', 'False']
# ['GEREL', 39.419998, 'False', 'False']
# ['GESAN', 50.849998, 'False', 'False']
# ['GIPTA', 32.540001, 'False', 'False']
# ['GLBMD', 37.860001, 'False', 'False']
# ['GLCVY', 40.400002, 'False', 'False']
# ['GLDTR', 209.39999, 'False', 'False']
# ['GLRYH', 13.08, 'False', 'False']
# ['GLYHO', 14.64, 'False', 'False']
# ['GMSTR', 194.7, 'False', 'False']
# ['GMTAS', 9.74, 'False', 'False']
# ['GOKNR', 26.42, 'False', 'False']
# ['GOLTS', 452.75, 'False', 'False']
# ['GOODY', 21.26, 'False', 'False']
# ['GOZDE', 26.74, 'False', 'False']
# ['GRNYO', 9.45, 'False', 'False']
# ['GRSEL', 147.10001, 'False', 'False']
# ['GRTRK', 59.849998, 'False', 'False']
# ['GSDDE', 9.12, 'False', 'False']
# ['GSDHO', 4.08, 'False', 'False']
# ['GSRAY', 8.56, 'False', 'False']
# ['GUBRF', 142.0, 'False', 'False']
# ['GWIND', 29.200001, 'False', 'False']
# ['GZNMI', 27.24, 'False', 'False']
# ['HALKB', 18.360001, 'False', 'False']
# ['HATEK', 13.66, 'False', 'False']
# ['HATSN', 49.52, 'False', 'False']
# ['HDFGS', 1.86, 'False', 'False']
# ['HEDEF', 23.700001, 'False', 'False']
# ['HEKTS', 12.83, 'False', 'False']
# ['HKTM', 16.110001, 'False', 'False']
# ['HLGYO', 2.92, 'False', 'False']
# ['HTTBT', 68.550003, 'False', 'False']
# ['HUBVC', 10.51, 'False', 'False']
# ['HUNER', 3.76, 'False', 'False']
# ['HURGZ', 3.85, 'False', 'False']
# ['ICBCT', 14.15, 'False', 'False']
# ['ICUGS', 12.11, 'False', 'False']
# ['IDGYO', 6.17, 'False', 'False']
# ['IEYHO', 4.93, 'False', 'False']
# ['IHAAS', 26.6, 'False', 'False']
# ['IHEVA', 3.64, 'False', 'False']
# ['IHGZT', 1.22, 'False', 'False']
# ['IHLAS', 1.22, 'False', 'False']
# ['IHLGM', 1.49, 'False', 'False']
# ['IHYAY', 5.43, 'False', 'False']
# ['IMASM', 12.8, 'False', 'False']
# ['INDES', 8.14, 'False', 'False']
# ['INFO', 10.13, 'False', 'False']
# ['INGRM', 502.0, 'False', 'False']
# ['INTEM', 235.8, 'False', 'False']
# ['INVEO', 41.580002, 'False', 'False']
# ['INVES', 337.5, 'False', 'False']
# ['IPEKE', 38.0, 'False', 'False']
# ['ISATR', 4004000.0, 'False', 'False']
# ['ISBIR', 127.0, 'False', 'False']
# ['ISBTR', 755005.0, 'False', 'False']
# ['ISCTR', 15.86, 'False', 'False']
# ['ISDMR', 37.419998, 'False', 'False']
# ['ISFIN', 15.02, 'False', 'False']
# ['ISGSY', 25.719999, 'False', 'False']
# ['ISGYO', 15.89, 'False', 'False']
# ['ISKPL', 12.38, 'False', 'False']
# ['ISKUR', 6509765.0, 'False', 'False']
# ['ISMEN', 40.0, 'True', 'False']
# ['ISSEN', 11.48, 'False', 'False']
# ['ISYAT', 9.3, 'False', 'False']
# ['IZENR', 22.48, 'False', 'False']
# ['IZFAS', 45.080002, 'False', 'False']
# ['IZINV', 51.150002, 'False', 'False']
# ['IZMDC', 6.23, 'False', 'False']
# ['JANTS', 29.0, 'False', 'False']
# ['KAPLM', 223.0, 'False', 'False']
# ['KAREL', 15.2, 'False', 'False']
# ['KARSN', 16.6, 'False', 'False']
# ['KARTN', 116.0, 'False', 'False']
# ['KARYE', 30.799999, 'False', 'False']
# ['KATMR', 2.16, 'False', 'False']
# ['KAYSE', 26.860001, 'False', 'False']
# ['KBORU', 80.0, 'False', 'False']
# ['KCAER', 54.75, 'False', 'False']
# ['KCHOL', 217.0, 'False', 'False']
# ['KENT', 1010.0, 'False', 'False']
# ['KERVN', 2.01, 'False', 'False']
# ['KERVT', 17.15, 'False', 'False']
# ['KFEIN', 116.6, 'False', 'False']
# ['KGYO', 30.700001, 'False', 'False']
# ['KIMMR', 10.02, 'False', 'False']
# ['KLGYO', 5.23, 'False', 'False']
# ['KLKIM', 27.5, 'False', 'False']
# ['KLMSN', 28.700001, 'False', 'False']
# ['KLNMA', 15.9, 'False', 'False']
# ['KLRHO', 32.119999, 'False', 'False']
# ['KLSER', 44.080002, 'False', 'False']
# ['KLSYN', 5.23, 'False', 'False']
# ['KMPUR', 57.0, 'False', 'False']
# ['KNFRT', 10.53, 'False', 'False']
# ['KOCMT', 18.49, 'False', 'False']
# ['KONKA', 48.18, 'False', 'False']
# ['KONTR', 167.3, 'False', 'False']
# ['KONYA', 7702.5, 'False', 'False']
# ['KOPOL', 37.0, 'False', 'False']
# ['KORDS', 91.0, 'False', 'False']
# ['KOTON', 22.620001, 'False', 'False']
# ['KOZAA', 52.450001, 'False', 'False']
# ['KOZAL', 21.16, 'False', 'False']
# ['KRDMA', 24.040001, 'False', 'False']
# ['KRDMB', 21.9, 'False', 'False']
# ['KRDMD', 29.799999, 'False', 'False']
# ['KRGYO', 26.1, 'False', 'False']
# ['KRONT', 20.0, 'False', 'False']
# ['KRPLS', 7.62, 'False', 'False']
# ['KRSTL', 7.23, 'False', 'False']
# ['KRTEK', 29.200001, 'False', 'False']
# ['KRVGD', 25.780001, 'False', 'False']
# ['KSTUR', 7000.0, 'False', 'False']
# ['KTLEV', 45.799999, 'False', 'False']
# ['KTSKR', 68.849998, 'False', 'False']
# ['KUTPO', 90.050003, 'False', 'False']
# ['KUVVA', 44.0, 'False', 'True']
# ['KUYAS', 45.259998, 'False', 'False']
# ['KZBGY', 25.9, 'False', 'False']
# ['KZGYO', 20.959999, 'False', 'False']
# ['LIDER', 82.400002, 'False', 'False']
# ['LIDFA', 8.1, 'False', 'False']
# ['LILAK', 27.120001, 'False', 'False']
# ['LINK', 536.0, 'False', 'False']
# ['LKMNH', 111.8, 'False', 'False']
# ['LMKDC', 20.200001, 'False', 'False']
# ['LOGO', 98.349998, 'False', 'False']
# ['LRSHO', 3.8, 'False', 'False']
# ['LUKSK', 109.5, 'False', 'False']
# ['MAALT', 1118.0, 'False', 'False']
# ['MACKO', 89.0, 'False', 'False']
# ['MAGEN', 27.379999, 'False', 'False']
# ['MAKIM', 31.639999, 'False', 'False']
# ['MAKTK', 7.86, 'False', 'False']
# ['MANAS', 13.2, 'False', 'False']
# ['MARBL', 15.04, 'False', 'False']
# ['MARKA', 79.0, 'False', 'False']
# ['MARTI', 3.44, 'False', 'False']
# ['MAVI', 122.2, 'False', 'False']
# ['MEDTR', 35.599998, 'True', 'False']
# ['MEGAP', 7.99, 'False', 'False']
# ['MEGMT', 34.5, 'False', 'False']
# ['MEKAG', 54.799999, 'False', 'False']
# ['MEPET', 10.72, 'False', 'False']
# ['MERCN', 11.1, 'False', 'False']
# ['MERIT', 255.75, 'False', 'False']
# ['MERKO', 11.82, 'False', 'False']
# ['METRO', 2.84, 'False', 'False']
# ['METUR', 13.47, 'False', 'False']
# ['MGROS', 520.0, 'False', 'False']
# ['MHRGY', 5.09, 'True', 'False']
# ['MIATK', 62.299999, 'False', 'False']
# ['MIPAZ', 91.300003, 'False', 'False']
# ['MMCAS', 20.4, 'False', 'False']
# ['MNDRS', 12.15, 'False', 'False']
# ['MNDTR', 6.39, 'False', 'False']
# ['MOBTL', 5.19, 'False', 'False']
# ['MOGAN', 11.91, 'False', 'False']
# ['MPARK', 324.5, 'False', 'False']
# ['MPATA', 3128.0, 'False', 'False']
# ['MRGYO', 5.53, 'False', 'False']
# ['MRSHL', 1891.0, 'False', 'False']
# ['MSGYO', 13.86, 'False', 'False']
# ['MTRKS', 60.0, 'False', 'False']
# ['MTRYO', 9.12, 'False', 'False']
# ['MZHLD', 7.2, 'False', 'False']
# ['NATEN', 46.720001, 'False', 'False']
# ['NETAS', 68.650002, 'False', 'False']
# ['NIBAS', 16.040001, 'False', 'False']
# ['NTGAZ', 15.82, 'False', 'False']
# ['NTHOL', 35.82, 'False', 'False']
# ['NUGYO', 8.23, 'False', 'False']
# ['NUHCM', 244.39999, 'False', 'False']
# ['OBAMS', 36.880001, 'False', 'False']
# ['OBASE', 38.459999, 'False', 'False']
# ['ODAS', 8.61, 'False', 'False']
# ['ODINE', 67.300003, 'True', 'False']
# ['OFSYM', 38.02, 'False', 'False']
# ['ONCSM', 129.8, 'False', 'False']
# ['OPX30', 58.139999, 'False', 'False']
# ['ORCAY', 11.75, 'False', 'False']
# ['ORGE', 64.050003, 'False', 'False']
# ['ORMA', 227.0, 'False', 'False']
# ['OSMEN', 247.3, 'False', 'False']
# ['OSTIM', 5.61, 'False', 'False']
# ['OTKAR', 652.0, 'False', 'False']
# ['OTTO', 281.0, 'False', 'False']
# ['OYAKC', 61.049999, 'False', 'False']
# ['OYAYO', 37.52, 'False', 'False']
# ['OYLUM', 10.07, 'False', 'False']
# ['OYYAT', 40.299999, 'False', 'False']
# ['OZGYO', 5.4, 'False', 'False']
# ['OZKGY', 10.44, 'False', 'False']
# ['OZRDN', 52.900002, 'False', 'False']
# ['OZSUB', 30.0, 'False', 'False']
# ['PAGYO', 49.360001, 'False', 'False']
# ['PAMEL', 115.1, 'False', 'False']
# ['PAPIL', 138.5, 'False', 'False']
# ['PARSN', 109.2, 'False', 'False']
# ['PASEU', 64.050003, 'False', 'False']
# ['PATEK', 73.650002, 'False', 'False']
# ['PCILT', 19.940001, 'False', 'False']
# ['PEHOL', 28.4, 'False', 'False']
# ['PEKGY', 7.52, 'False', 'False']
# ['PENGD', 7.85, 'False', 'False']
# ['PENTA', 15.98, 'False', 'False']
# ['PETKM', 20.959999, 'False', 'False']
# ['PETUN', 84.199997, 'False', 'False']
# ['PGSUS', 226.5, 'False', 'False']
# ['PINSU', 23.799999, 'False', 'True']
# ['PKART', 97.5, 'False', 'False']
# ['PKENT', 291.0, 'False', 'False']
# ['PLTUR', 17.959999, 'False', 'False']
# ['PNLSN', 63.049999, 'False', 'False']
# ['PNSUT', 86.150002, 'False', 'False']
# ['POLHO', 13.04, 'False', 'False']
# ['POLTK', 8757.5, 'False', 'False']
# ['PRDGS', 6.23, 'False', 'False']
# ['PRKAB', 36.439999, 'False', 'False']
# ['PRKME', 24.700001, 'False', 'False']
# ['PRZMA', 35.799999, 'False', 'False']
# ['PSDTC', 90.5, 'False', 'False']
# ['PSGYO', 5.68, 'False', 'False']
# ['QNBFB', 300.5, 'False', 'False']
# ['QNBFL', 111.6, 'False', 'True']
# ['QPERP', 5151.0, 'False', 'False']
# ['QTEMZ', 349.10001, 'False', 'False']
# ['QUAGR', 3.19, 'False', 'False']
# ['RALYH', 228.3, 'False', 'False']
# ['RAYSG', 502.5, 'False', 'True']
# ['REEDR', 35.0, 'False', 'False']
# ['RGYAS', 123.4, 'False', 'False']
# ['RNPOL', 28.860001, 'False', 'False']
# ['RODRG', 132.0, 'False', 'False']
# ['RPAVS', 5734.0, 'False', 'False']
# ['RPFGY', 4903.0, 'False', 'False']
# ['RTALB', 11.5, 'False', 'False']
# ['RUBNS', 30.0, 'False', 'False']
# ['RYGYO', 48.400002, 'False', 'False']
# ['RYSAS', 55.0, 'False', 'False']
# ['SAFKR', 48.360001, 'False', 'False']
# ['SAHOL', 90.349998, 'False', 'False']
# ['SAMAT', 42.799999, 'False', 'False']
# ['SANEL', 25.0, 'False', 'False']
# ['SANFM', 72.75, 'False', 'False']
# ['SANKO', 24.299999, 'False', 'False']
# ['SARKY', 35.639999, 'False', 'False']
# ['SASA', 44.200001, 'False', 'False']
# ['SAYAS', 66.599998, 'False', 'False']
# ['SDTTR', 246.2, 'False', 'False']
# ['SEGYO', 4.12, 'False', 'False']
# ['SEKFK', 9.58, 'False', 'False']
# ['SEKUR', 10.79, 'False', 'False']
# ['SELEC', 45.939999, 'False', 'False']
# ['SELGD', 42.5, 'False', 'False']
# ['SELVA', 13.21, 'False', 'False']
# ['SEYKM', 9.23, 'False', 'False']
# ['SILVR', 18.719999, 'False', 'False']
# ['SISE', 47.720001, 'False', 'False']
# ['SKBNK', 4.15, 'False', 'False']
# ['SKTAS', 5.16, 'False', 'False']
# ['SKYLP', 109.4, 'False', 'False']
# ['SKYMD', 14.7, 'False', 'False']
# ['SMART', 34.700001, 'False', 'False']
# ['SMRTG', 51.900002, 'False', 'False']
# ['SNGYO', 5.22, 'False', 'False']
# ['SNICA', 7.1, 'False', 'False']
# ['SNKRN', 43.98, 'False', 'False']
# ['SNPAM', 81.550003, 'False', 'False']
# ['SODSN', 133.60001, 'False', 'False']
# ['SOKE', 14.5, 'False', 'False']
# ['SOKM', 60.950001, 'False', 'False']
# ['SONME', 92.0, 'False', 'False']
# ['SRVGY', 295.0, 'False', 'False']
# ['SUMAS', 390.0, 'False', 'False']
# ['SUNTK', 19.74, 'False', 'False']
# ['SURGY', 50.450001, 'False', 'False']
# ['SUWEN', 31.08, 'False', 'False']
# ['TABGD', 200.60001, 'False', 'False']
# ['TARKM', 452.0, 'False', 'False']
# ['TATEN', 32.080002, 'False', 'False']
# ['TATGD', 24.799999, 'False', 'False']
# ['TAVHL', 248.0, 'False', 'False']
# ['TBORG', 95.400002, 'False', 'False']
# ['TCELL', 98.050003, 'False', 'False']
# ['TDGYO', 10.6, 'False', 'False']
# ['TEKTU', 5.09, 'False', 'False']
# ['TERA', 37.080002, 'False', 'False']
# ['TETMT', 12897.5, 'False', 'False']
# ['TEZOL', 16.75, 'False', 'False']
# ['TGSAS', 67.099998, 'False', 'False']
# ['THYAO', 301.0, 'False', 'False']
# ['TKFEN', 55.049999, 'False', 'False']
# ['TKNSA', 30.76, 'False', 'False']
# ['TLMAN', 105.4, 'False', 'False']
# ['TMPOL', 79.5, 'False', 'False']
# ['TMSN', 127.0, 'False', 'False']
# ['TNZTP', 56.0, 'False', 'False']
# ['TOASO', 340.0, 'False', 'False']
# ['TRCAS', 27.620001, 'False', 'False']
# ['TRGYO', 49.799999, 'False', 'False']
# ['TRILC', 26.0, 'False', 'False']
# ['TSGYO', 14.82, 'False', 'False']
# ['TSKB', 11.88, 'False', 'False']
# ['TSPOR', 2.21, 'False', 'False']
# ['TTKOM', 48.099998, 'False', 'False']
# ['TTRAK', 912.0, 'False', 'False']
# ['TUCLK', 12.4, 'False', 'False']
# ['TUKAS', 7.34, 'False', 'False']
# ['TUPRS', 165.39999, 'False', 'False']
# ['TUREX', 60.0, 'False', 'False']
# ['TURGG', 585.0, 'False', 'False']
# ['TURSG', 76.949997, 'False', 'False']
# ['UFUK', 460.0, 'False', 'False']
# ['ULAS', 20.719999, 'False', 'False']
# ['ULKER', 162.0, 'False', 'False']
# ['ULUFA', 13.39, 'False', 'False']
# ['ULUSE', 170.2, 'False', 'False']
# ['ULUUN', 28.139999, 'False', 'False']
# ['UMPAS', 11.01, 'False', 'False']
# ['UNLU', 15.94, 'False', 'False']
# ['USAK', 12.8, 'False', 'False']
# ['USDTR', 3100.0, 'False', 'False']
# ['UZERB', 750.0, 'False', 'False']
# ['VAKBN', 22.6, 'False', 'False']
# ['VAKFN', 3.17, 'False', 'False']
# ['VAKKO', 129.0, 'False', 'False']
# ['VANGD', 18.200001, 'False', 'False']
# ['VBTYZ', 28.219999, 'False', 'False']
# ['VERTU', 48.799999, 'False', 'False']
# ['VERUS', 304.75, 'False', 'False']
# ['VESBE', 21.08, 'False', 'False']
# ['VESTL', 79.599998, 'False', 'False']
# ['VKFYO', 28.0, 'False', 'False']
# ['VKGYO', 2.04, 'False', 'False']
# ['VKING', 39.639999, 'False', 'False']
# ['VRGYO', 21.6, 'False', 'False']
# ['YAPRK', 466.0, 'False', 'False']
# ['YATAS', 34.119999, 'False', 'False']
# ['YAYLA', 17.139999, 'False', 'False']
# ['YBTAS', 167100.0, 'False', 'False']
# ['YEOTK', 187.7, 'False', 'False']
# ['YESIL', 4.44, 'False', 'False']
# ['YGGYO', 51.450001, 'False', 'False']
# ['YGYO', 9.39, 'False', 'False']
# ['YKBNK', 33.18, 'False', 'False']
# ['YKSLN', 20.5, 'False', 'False']
# ['YONGA', 72.0, 'False', 'False']
# ['YUNSA', 79.150002, 'False', 'False']
# ['YYAPI', 6.18, 'False', 'False']
# ['YYLGD', 11.65, 'False', 'False']
# ['Z30EA', 135.10001, 'False', 'False']
# ['Z30KE', 103.75, 'False', 'False']
# ['Z30KP', 148.10001, 'False', 'False']
# ['ZEDUR', 10.94, 'False', 'False']
# ['ZELOT', 109.15, 'False', 'False']
# ['ZGOLD', 247.10001, 'False', 'False']
# ['ZOREN', 5.41, 'False', 'False']
# ['ZPBDL', 155.10001, 'False', 'True']
# ['ZPLIB', 172.7, 'False', 'False']
# ['ZPT10', 80.839996, 'False', 'False']
# ['ZPX30', 148.5, 'False', 'False']
# ['ZRE20', 121.3, 'False', 'False']
# ['ZRGYO', 7.9, 'False', 'False']
# ['ZSR25', 40.16, 'False', 'False']
# ['ZTM15', 150.0, 'False', 'False']
#     Hisse Adı  Son Fiyat Giriş Sinyali Çıkış Sinyali
# 175     EKGYO   9.600000          True         False
# 282     ISMEN  40.000000          True         False
# 360     MEDTR  35.599998          True         False
# 371     MHRGY   5.090000          True         False
# 397     ODINE  67.300003          True         False
