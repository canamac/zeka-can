# %% [markdown]
# <a href="https://colab.research.google.com/github/canamac/zeka-can/blob/main/999_ALMA_Haftal%C4%B1k.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/rongardF/tvdatafeed tradingview-screener

import pandas as pd
import numpy as np
from tvDatafeed import TvDatafeed, Interval
from tradingview_screener import get_all_symbols
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

def alma(series, window=20, sigma=6, offset=0.85):
    """
    Calculate the Arnaud Legoux Moving Average (ALMA) for a given series.

    :param series: pandas Series of prices.
    :param window: int, window length for the moving average.
    :param sigma: float, standard deviation for the Gaussian distribution.
    :param offset: float, offset for the Gaussian distribution.
    :return: pandas Series with the ALMA values.
    """
    m = (window - 1) * offset
    s = window / sigma

    def gaussian_weight(x, m, s):
        return np.exp(-((x - m) ** 2) / (2 * s ** 2))

    weights = np.array([gaussian_weight(i, m, s) for i in range(window)])
    weights /= np.sum(weights)

    alma = series.rolling(window=window).apply(lambda x: np.dot(x, weights), raw=True)
    return alma


tv = TvDatafeed()
Hisseler = get_all_symbols(market='turkey')
print(Hisseler)
Hisseler = [symbol.replace('BIST:', '') for symbol in Hisseler]
Hisseler = sorted(Hisseler)

#Raporlama için kullanılacak başlıklar
Titles = ['Hisse Adı', 'Son Fiyat','Giriş Sinyali', 'Çıkış Sinyali']

df_signals = pd.DataFrame(columns=Titles)

for i in range(0,len(Hisseler)):
    #print(Hisseler[i])
    try:
        data = tv.get_hist(symbol=Hisseler[i], exchange='BIST', interval=Interval.in_weekly, n_bars=100)
        data = data.reset_index()
        data['ALMA'] = alma(data['close'],20,6,0.85)
        data['datetime'] = pd.to_datetime(data['datetime'])
        data.set_index('datetime', inplace=True)
        Buy = False
        Sell = False
        Signals = data.tail(2)
        Signals = Signals.reset_index()
        last_rows = data.iloc[-2:]
        Buy = (Signals.loc[1,'close'] > Signals.loc[1,'ALMA']) and (Signals.loc[0,'close'] < Signals.loc[0,'ALMA'])
        Sell = (Signals.loc[1,'close'] < Signals.loc[1,'ALMA']) and (Signals.loc[0,'close'] > Signals.loc[0,'ALMA'])
        Last_Price = Signals.loc[1, 'close']
        L1 = [Hisseler[i] ,Last_Price, str(Buy), str(Sell)]
        df_signals.loc[len(df_signals)] = L1
        print(L1)
    except:
        pass

df_True = df_signals[(df_signals['Giriş Sinyali'] == 'True')]
print(df_True.to_string())
# Out:
# Collecting git+https://github.com/rongardF/tvdatafeed
#   Cloning https://github.com/rongardF/tvdatafeed to /tmp/pip-req-build-shvvdrtz
#   Running command git clone --filter=blob:none --quiet https://github.com/rongardF/tvdatafeed /tmp/pip-req-build-shvvdrtz
#   Resolved https://github.com/rongardF/tvdatafeed to commit e6f6aaa7de439ac6e454d9b26d2760ded8dc4923
#   Preparing metadata (setup.py) ... done
# Collecting tradingview-screener
#   Downloading tradingview_screener-2.5.0-py3-none-any.whl (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.5/43.5 kB 473.5 kB/s eta 0:00:00
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tvdatafeed==2.1.0) (67.7.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from tvdatafeed==2.1.0) (2.0.3)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from tvdatafeed==2.1.0) (1.8.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from tvdatafeed==2.1.0) (2.31.0)
# Collecting pandas (from tvdatafeed==2.1.0)
#   Downloading pandas-2.2.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 18.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas->tvdatafeed==2.1.0) (1.25.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->tvdatafeed==2.1.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->tvdatafeed==2.1.0) (2023.4)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->tvdatafeed==2.1.0) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->tvdatafeed==2.1.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->tvdatafeed==2.1.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->tvdatafeed==2.1.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->tvdatafeed==2.1.0) (2024.6.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas
# ['ALTNY', 84.300003, 'False', 'False']
# ['ALVES', 41.32, 'False', 'False']
# ['ANELE', 18.32, 'False', 'False']
# ['ANGEN', 11.91, 'False', 'False']
# ['ANHYT', 131.10001, 'False', 'False']
# ['ANSGR', 113.2, 'False', 'False']
# ['APBDL', 23.549999, 'False', 'False']
# ['APLIB', 39.830002, 'False', 'False']
# ['APX30', 27.34, 'False', 'False']
# ['APYKF', 1750.0, 'False', 'False']
# ['APYKS', 1476.0, 'False', 'False']
# ['APYMD', 3498.0, 'False', 'False']
# ['ARASE', 59.549999, 'False', 'False']
# ['ARCLK', 175.10001, 'False', 'True']
# ['ARDYZ', 40.16, 'False', 'False']
# ['ARENA', 41.560001, 'False', 'False']
# ['ARSAN', 17.5, 'False', 'False']
# ['ARTMS', 44.66, 'False', 'False']
# ['ARZUM', 65.0, 'False', 'False']
# ['ASELS', 59.349998, 'True', 'False']
# ['ASGYO', 13.38, 'False', 'False']
# ['ASTOR', 94.0, 'False', 'False']
# ['ASUZU', 92.099998, 'False', 'False']
# ['ATAGY', 13.05, 'False', 'False']
# ['ATAKP', 49.0, 'False', 'False']
# ['ATATP', 139.7, 'False', 'False']
# ['ATEKS', 157.0, 'False', 'False']
# ['ATLAS', 5.03, 'False', 'False']
# ['ATSYH', 43.099998, 'False', 'False']
# ['AVGYO', 8.1, 'False', 'False']
# ['AVHOL', 35.740002, 'False', 'False']
# ['AVOD', 3.44, 'False', 'False']
# ['AVPGY', 43.119999, 'False', 'False']
# ['AVTUR', 15.95, 'False', 'False']
# ['AYCES', 639.0, 'False', 'False']
# ['AYDEM', 34.18, 'False', 'False']
# ['AYEN', 31.08, 'False', 'False']
# ['AYES', 46.099998, 'False', 'False']
# ['AYGAZ', 174.39999, 'False', 'False']
# ['AZTEK', 69.400002, 'False', 'False']
# ['BAGFS', 23.280001, 'False', 'False']
# ['BAKAB', 42.5, 'False', 'False']
# ['BALAT', 33.0, 'False', 'False']
# ['BANVT', 293.25, 'False', 'False']
# ['BARMA', 18.01, 'False', 'False']
# ['BASCM', 13.71, 'False', 'False']
# ['BASGZ', 30.24, 'False', 'False']
# ['BAYRK', 62.5, 'False', 'False']
# ['BEGYO', 3.9, 'False', 'False']
# ['BERA', 17.200001, 'False', 'False']
# ['BEYAZ', 23.9, 'False', 'False']
# ['BFREN', 876.5, 'False', 'False']
# ['BIENY', 34.84, 'False', 'False']
# ['BIGCH', 31.799999, 'False', 'False']
# ['BIMAS', 553.0, 'False', 'False']
# ['BINHO', 392.0, 'False', 'False']
# ['BIOEN', 20.18, 'False', 'False']
# ['BIZIM', 34.099998, 'False', 'False']
# ['BJKAS', 33.299999, 'False', 'False']
# ['BLCYT', 19.25, 'False', 'False']
# ['BMSCH', 24.9, 'False', 'True']
# ['BMSTL', 39.080002, 'False', 'False']
# ERROR:tvDatafeed.main:Connection to remote host was lost.
# ERROR:tvDatafeed.main:no data, please check the exchange and symbol
# ['BOBET', 28.299999, 'False', 'False']
# ['BORLS', 33.099998, 'False', 'False']
# ['BORSK', 31.879999, 'False', 'False']
# ['BOSSA', 16.85, 'False', 'False']
# ['BRISA', 111.7, 'False', 'False']
# ['BRKO', 9.93, 'False', 'False']
# ['BRKSN', 37.619999, 'False', 'False']
# ['BRKVY', 59.650002, 'False', 'False']
# ['BRLSM', 18.620001, 'False', 'False']
# ['BRMEN', 5.32, 'False', 'False']
# ['BRSAN', 474.0, 'False', 'False']
# ['BRYAT', 2305.0, 'False', 'False']
# ['BSOKE', 29.92, 'False', 'False']
# ['BTCIM', 145.0, 'False', 'False']
# ['BUCIM', 8.17, 'False', 'False']
# ['BURCE', 280.0, 'False', 'False']
# ['BURVA', 135.2, 'False', 'False']
# ['BVSAN', 105.0, 'False', 'False']
# ['BYDNR', 25.9, 'False', 'False']
# ['CANTE', 16.85, 'False', 'False']
# ['CASA', 84.0, 'False', 'False']
# ['CATES', 45.759998, 'False', 'False']
# ['CCOLA', 806.0, 'False', 'False']
# ['CELHA', 24.040001, 'False', 'False']
# ['CEMAS', 4.27, 'False', 'False']
# ['CEMTS', 12.3, 'False', 'False']
# ['CEOEM', 21.799999, 'False', 'False']
# ['CIMSA', 30.52, 'False', 'False']
# ['CLEBI', 2127.0, 'False', 'False']
# ['CMBTN', 3020.0, 'False', 'False']
# ['CMENT', 400.0, 'False', 'False']
# ['CONSE', 5.39, 'False', 'False']
# ['COSMO', 125.0, 'False', 'False']
# ['CRDFA', 7.8, 'False', 'False']
# ['CRFSA', 117.9, 'False', 'False']
# ['CUSAN', 23.799999, 'False', 'False']
# ['CVKMD', 473.75, 'False', 'True']
# ['CWENE', 202.2, 'False', 'False']
# ['DAGHL', 18.0, 'False', 'False']
# ['DAGI', 8.5, 'False', 'True']
# ['DAPGM', 32.48, 'False', 'False']
# ['DARDL', 6.2, 'False', 'False']
# ['DENGE', 4.56, 'False', 'False']
# ['DERHL', 7.46, 'False', 'False']
# ['DERIM', 44.599998, 'False', 'False']
# ['DESA', 30.48, 'False', 'False']
# ['DESPC', 40.880001, 'False', 'False']
# ['DEVA', 90.5, 'False', 'False']
# ['DGATE', 39.5, 'False', 'False']
# ['DGGYO', 33.240002, 'False', 'False']
# ['DGNMO', 13.7, 'False', 'True']
# ['DIRIT', 21.6, 'False', 'False']
# ['DITAS', 15.95, 'False', 'False']
# ['DMRGD', 14.14, 'False', 'False']
# ['DMSAS', 7.05, 'False', 'False']
# ['DNISI', 15.8, 'False', 'False']
# ['DOAS', 275.25, 'False', 'False']
# ['DOBUR', 190.10001, 'False', 'False']
# ['DOCO', 5370.0, 'False', 'False']
# ['DOFER', 39.16, 'False', 'True']
# ['DOGUB', 27.120001, 'False', 'False']
# ['DOHOL', 15.95, 'False', 'False']
# ['DOKTA', 30.200001, 'False', 'False']
# ['DURDO', 14.7, 'False', 'False']
# ['DYOBY', 50.849998, 'False', 'False']
# ['DZGYO', 4.64, 'False', 'False']
# ['EBEBK', 44.459999, 'False', 'False']
# ['ECILC', 53.150002, 'False', 'True']
# ['ECZYT', 232.3, 'False', 'False']
# ['EDATA', 16.73, 'False', 'False']
# ['EDIP', 25.639999, 'False', 'False']
# ['EGEEN', 12397.5, 'False', 'False']
# ['EGEPO', 20.4, 'False', 'True']
# ['EGGUB', 40.040001, 'False', 'False']
# ['EGPRO', 225.5, 'False', 'False']
# ['EGSER', 3.52, 'False', 'False']
# ['EKGYO', 9.07, 'False', 'False']
# ['EKIZ', 77.199997, 'True', 'False']
# ['EKOS', 34.919998, 'False', 'False']
# ['EKSUN', 59.299999, 'False', 'False']
# ['ELITE', 27.879999, 'False', 'False']
# ['EMKEL', 12.65, 'False', 'False']
# ['EMNIS', 384.0, 'False', 'False']
# ['ENERY', 178.5, 'False', 'False']
# ['ENJSA', 63.700001, 'False', 'False']
# ['ENKAI', 42.0, 'False', 'False']
# ['ENSRI', 19.74, 'False', 'False']
# ['ENTRA', 10.3, 'False', 'False']
# ['EPLAS', 7.04, 'False', 'False']
# ['ERBOS', 223.3, 'False', 'False']
# ['ERCB', 123.9, 'False', 'False']
# ['EREGL', 51.599998, 'False', 'False']
# ['ERSU', 20.98, 'False', 'False']
# ['ESCAR', 332.0, 'False', 'False']
# ['ESCOM', 66.099998, 'False', 'False']
# ['ESEN', 19.4, 'True', 'False']
# ['ETILR', 24.360001, 'False', 'False']
# ['ETYAT', 14.75, 'False', 'False']
# ['EUHOL', 3.31, 'False', 'True']
# ['EUKYO', 22.42, 'False', 'False']
# ['EUPWR', 105.9, 'False', 'False']
# ['EUREN', 14.66, 'False', 'False']
# ['EUYO', 14.11, 'False', 'False']
# ['EYGYO', 11.07, 'False', 'False']
# ['FADE', 15.56, 'False', 'False']
# ['FENER', 152.0, 'False', 'False']
# ['FLAP', 7.9, 'False', 'False']
# ['FMIZP', 315.0, 'False', 'False']
# ['FONET', 16.959999, 'False', 'False']
# ['FORMT', 3.06, 'False', 'False']
# ['FORTE', 55.849998, 'False', 'False']
# ['FRIGO', 7.84, 'False', 'False']
# ['FROTO', 1079.0, 'False', 'False']
# ['FZLGY', 12.33, 'False', 'True']
# ['GARAN', 104.9, 'False', 'False']
# ['GARFA', 25.540001, 'False', 'False']
# ['GEDIK', 14.32, 'False', 'False']
# ['GEDZA', 24.360001, 'False', 'False']
# ['GENIL', 66.849998, 'False', 'False']
# ['GENTS', 8.88, 'False', 'False']
# ['GEREL', 41.040001, 'False', 'True']
# ['GESAN', 53.049999, 'False', 'False']
# ['GIPTA', 31.74, 'False', 'False']
# ['GLBMD', 37.900002, 'False', 'False']
# ['GLCVY', 40.540001, 'False', 'False']
# ['GLDTR', 209.35001, 'False', 'False']
# ['GLRYH', 11.75, 'True', 'False']
# ['GLYHO', 16.059999, 'False', 'False']
# ['GMSTR', 196.10001, 'False', 'False']
# ['GMTAS', 9.35, 'False', 'False']
# ['GOKNR', 21.9, 'False', 'False']
# ['GOLTS', 420.25, 'False', 'False']
# ['GOODY', 21.42, 'False', 'True']
# ['GOZDE', 26.559999, 'False', 'False']
# ['GRNYO', 9.67, 'False', 'False']
# ['GRSEL', 133.39999, 'False', 'False']
# ['GRTRK', 63.849998, 'False', 'False']
# ['GSDDE', 9.79, 'False', 'False']
# ['GSDHO', 4.13, 'False', 'False']
# ['GSRAY', 8.23, 'False', 'False']
# ['GUBRF', 145.89999, 'False', 'False']
# ['GWIND', 29.42, 'False', 'False']
# ['GZNMI', 35.119999, 'False', 'False']
# ['HALKB', 19.48, 'False', 'False']
# ['HATEK', 13.27, 'False', 'False']
# ['HATSN', 52.299999, 'False', 'False']
# ['HDFGS', 1.84, 'False', 'False']
# ['HEDEF', 25.200001, 'False', 'False']
# ['HEKTS', 13.5, 'False', 'False']
# ['HKTM', 17.360001, 'False', 'False']
# ['HLGYO', 2.95, 'False', 'False']
# ['HOROZ', 47.720001, 'False', 'False']
# ['HRKET', 66.400002, 'False', 'False']
# ['HTTBT', 66.050003, 'False', 'False']
# ['HUBVC', 10.78, 'False', 'False']
# ['HUNER', 4.06, 'False', 'False']
# ['HURGZ', 4.0, 'False', 'False']
# ['ICBCT', 15.1, 'False', 'False']
# ['ICUGS', 13.4, 'False', 'False']
# ['IDGYO', 6.5, 'False', 'False']
# ['IEYHO', 5.06, 'True', 'False']
# ['IHAAS', 25.120001, 'False', 'False']
# ['IHEVA', 3.58, 'False', 'False']
# ['IHGZT', 1.24, 'False', 'False']
# ['IHLAS', 1.32, 'False', 'False']
# ['IHLGM', 1.57, 'False', 'False']
# ['IHYAY', 5.04, 'False', 'False']
# ['IMASM', 14.07, 'False', 'False']
# ['INDES', 8.65, 'False', 'False']
# ['INFO', 10.33, 'False', 'False']
# ['INGRM', 515.5, 'False', 'False']
# ['INTEM', 253.25, 'False', 'False']
# ['INVEO', 42.759998, 'False', 'False']
# ['INVES', 333.0, 'True', 'False']
# ['IPEKE', 38.200001, 'False', 'False']
# ['ISATR', 3499997.5, 'False', 'False']
# ['ISBIR', 140.0, 'False', 'False']
# ['ISBTR', 799000.0, 'False', 'False']
# ['ISCTR', 16.18, 'False', 'False']
# ['ISDMR', 38.48, 'False', 'False']
# ['ISFIN', 15.43, 'False', 'False']
# ['ISGSY', 26.82, 'False', 'False']
# ['ISGYO', 15.73, 'False', 'True']
# ['ISKPL', 12.07, 'False', 'False']
# ['ISMEN', 34.400002, 'False', 'True']
# ['ISSEN', 10.48, 'False', 'False']
# ['ISYAT', 9.7, 'False', 'False']
# ['IZENR', 22.700001, 'False', 'False']
# ['IZFAS', 41.0, 'False', 'False']
# ['IZINV', 54.0, 'False', 'False']
# ['IZMDC', 6.47, 'False', 'False']
# ['JANTS', 31.0, 'False', 'False']
# ['KAPLM', 239.5, 'False', 'False']
# ['KAREL', 15.99, 'False', 'False']
# ['KARSN', 13.31, 'False', 'False']
# ['KARTN', 113.6, 'False', 'False']
# ['KARYE', 34.740002, 'False', 'False']
# ['KATMR', 2.03, 'False', 'False']
# ['KAYSE', 27.459999, 'False', 'False']
# ['KBORU', 85.0, 'False', 'False']
# ['KCAER', 54.549999, 'False', 'False']
# ['KCHOL', 217.5, 'False', 'False']
# ['KENT', 1101.0, 'False', 'False']
# ['KERVN', 1.61, 'False', 'False']
# ['KERVT', 14.33, 'False', 'False']
# ['KFEIN', 138.0, 'False', 'False']
# ['KGYO', 35.360001, 'True', 'False']
# ['KIMMR', 10.4, 'False', 'False']
# ['KLGYO', 5.54, 'False', 'False']
# ['KLKIM', 26.780001, 'True', 'False']
# ['KLMSN', 28.4, 'False', 'False']
# ['KLNMA', 17.440001, 'False', 'True']
# ['KLRHO', 34.0, 'False', 'False']
# ['KLSER', 46.599998, 'False', 'False']
# ['KLSYN', 5.36, 'False', 'False']
# ['KMPUR', 57.0, 'False', 'False']
# ['KNFRT', 11.95, 'False', 'False']
# ['KOCMT', 18.299999, 'False', 'False']
# ['KONKA', 50.25, 'False', 'False']
# ['KONTR', 175.2, 'False', 'False']
# ['KONYA', 8055.0, 'False', 'False']
# ['KOPOL', 37.580002, 'False', 'False']
# ['KORDS', 92.5, 'False', 'False']
# ['KOTON', 23.84, 'False', 'False']
# ['KOZAA', 54.599998, 'False', 'False']
# ['KOZAL', 21.440001, 'False', 'False']
# ['KRDMA', 24.32, 'False', 'False']
# ['KRDMB', 22.540001, 'False', 'False']
# ['KRDMD', 30.1, 'False', 'False']
# ['KRGYO', 25.620001, 'False', 'False']
# ['KRONT', 22.700001, 'False', 'False']
# ['KRPLS', 7.91, 'False', 'False']
# ['KRSTL', 7.67, 'False', 'False']
# ['KRTEK', 30.700001, 'False', 'False']
# ['KRVGD', 25.9, 'False', 'False']
# ['KSTUR', 7750.0, 'False', 'False']
# ['KTLEV', 44.02, 'False', 'False']
# ['KTSKR', 70.5, 'False', 'False']
# ERROR:tvDatafeed.main:Connection to remote host was lost.
# ERROR:tvDatafeed.main:no data, please check the exchange and symbol
# ['KUVVA', 46.080002, 'False', 'False']
# ['KUYAS', 48.400002, 'False', 'False']
# ['KZBGY', 24.200001, 'False', 'False']
# ['KZGYO', 21.280001, 'False', 'False']
# ['LIDER', 77.150002, 'False', 'False']
# ['LIDFA', 8.44, 'False', 'False']
# ['LILAK', 28.18, 'False', 'False']
# ['LINK', 482.75, 'False', 'False']
# ['LKMNH', 105.2, 'False', 'False']
# ['LMKDC', 20.959999, 'False', 'False']
# ['LOGO', 89.199997, 'False', 'False']
# ['LRSHO', 3.73, 'False', 'False']
# ['LUKSK', 119.7, 'False', 'False']
# ['MAALT', 1146.0, 'False', 'False']
# ['MACKO', 82.550003, 'True', 'False']
# ['MAGEN', 24.68, 'False', 'False']
# ['MAKIM', 30.440001, 'False', 'False']
# ['MAKTK', 7.57, 'False', 'False']
# ['MANAS', 11.6, 'False', 'False']
# ERROR:tvDatafeed.main:Connection to remote host was lost.
# ERROR:tvDatafeed.main:no data, please check the exchange and symbol
# ['MARKA', 82.150002, 'False', 'False']
# ['MARTI', 3.59, 'False', 'False']
# ['MAVI', 112.0, 'False', 'False']
# ['MEDTR', 33.259998, 'False', 'False']
# ['MEGAP', 9.05, 'False', 'False']
# ['MEGMT', 35.5, 'False', 'False']
# ['MEKAG', 59.099998, 'False', 'False']
# ['MEPET', 11.05, 'False', 'False']
# ['MERCN', 11.18, 'False', 'False']
# ['MERIT', 177.0, 'False', 'False']
# ['MERKO', 12.91, 'False', 'False']
# ['METRO', 2.71, 'False', 'False']
# ['METUR', 14.3, 'False', 'False']
# ['MGROS', 516.0, 'False', 'False']
# ['MHRGY', 4.65, 'False', 'False']
# ['MIATK', 56.5, 'True', 'False']
# ['MIPAZ', 80.400002, 'True', 'False']
# ['MMCAS', 22.780001, 'False', 'False']
# ['MNDRS', 15.13, 'False', 'False']
# ['MNDTR', 6.2, 'False', 'False']
# ['MOBTL', 5.7, 'False', 'False']
# ['MOGAN', 13.27, 'False', 'False']
# ['MPARK', 338.25, 'False', 'False']
# ['MPATA', 3110.0, 'False', 'False']
# ['MRGYO', 5.81, 'False', 'False']
# ['MRSHL', 1965.0, 'False', 'False']
# ['MSGYO', 13.7, 'False', 'False']
# ['MTRKS', 67.900002, 'False', 'True']
# ['MTRYO', 8.97, 'True', 'False']
# ['MZHLD', 7.72, 'False', 'False']
# ['NATEN', 42.240002, 'False', 'False']
# ['NETAS', 72.699997, 'False', 'False']
# ['NIBAS', 17.25, 'False', 'False']
# ['NTGAZ', 16.129999, 'False', 'False']
# ['NTHOL', 33.200001, 'False', 'False']
# ['NUGYO', 7.93, 'False', 'False']
# ['NUHCM', 253.25, 'False', 'False']
# ['OBAMS', 37.18, 'False', 'False']
# ['OBASE', 40.16, 'False', 'False']
# ['ODAS', 8.53, 'False', 'False']
# ['ODINE', 60.75, 'False', 'False']
# ['OFSYM', 41.0, 'False', 'False']
# ['ONCSM', 136.0, 'False', 'False']
# ['ONRYT', 72.949997, 'False', 'False']
# ['OPX30', 57.720001, 'False', 'False']
# ['ORCAY', 11.39, 'False', 'False']
# ['ORGE', 64.550003, 'False', 'False']
# ['ORMA', 259.0, 'False', 'False']
# ['OSMEN', 255.75, 'False', 'True']
# ['OSTIM', 5.98, 'False', 'False']
# ['OTKAR', 619.0, 'False', 'False']
# ['OTTO', 289.0, 'False', 'False']
# ['OYAKC', 61.25, 'False', 'False']
# ['OYAYO', 34.48, 'False', 'False']
# ['OYLUM', 10.38, 'False', 'False']
# ['OYYAT', 41.740002, 'False', 'False']
# ['OZGYO', 5.8, 'False', 'False']
# ['OZKGY', 8.84, 'False', 'False']
# ['OZRDN', 58.900002, 'False', 'False']
# ['OZSUB', 31.34, 'True', 'False']
# ['OZYSR', 26.879999, 'False', 'False']
# ['PAGYO', 48.099998, 'False', 'False']
# ['PAMEL', 119.3, 'False', 'False']
# ['PAPIL', 135.89999, 'True', 'False']
# ['PARSN', 111.5, 'False', 'False']
# ['PASEU', 67.949997, 'False', 'False']
# ['PATEK', 73.949997, 'False', 'False']
# ['PCILT', 19.190001, 'False', 'False']
# ['PEHOL', 25.08, 'False', 'False']
# ['PEKGY', 7.77, 'False', 'False']
# ['PENGD', 7.96, 'True', 'False']
# ['PENTA', 15.89, 'False', 'False']
# ['PETKM', 21.540001, 'False', 'False']
# ['PETUN', 85.650002, 'False', 'False']
# ['PGSUS', 230.3, 'False', 'False']
# ['PINSU', 25.48, 'False', 'False']
# ['PKART', 109.0, 'False', 'False']
# ['PKENT', 307.5, 'False', 'False']
# ['PLTUR', 17.059999, 'True', 'False']
# ['PNLSN', 67.699997, 'False', 'False']
# ['PNSUT', 84.5, 'False', 'False']
# ['POLHO', 13.27, 'False', 'False']
# ['POLTK', 9300.0, 'False', 'False']
# ['PRDGS', 6.5, 'False', 'False']
# ['PRKAB', 37.619999, 'False', 'True']
# ['PRKME', 24.08, 'True', 'False']
# ['PRZMA', 35.52, 'False', 'False']
# ['PSDTC', 90.349998, 'False', 'False']
# ['PSGYO', 6.02, 'False', 'False']
# ['QNBFB', 345.25, 'False', 'True']
# ['QNBFL', 134.89999, 'False', 'False']
# ['QPERP', 5058.0, 'True', 'False']
# ['QTEMZ', 340.60001, 'False', 'False']
# ['QUAGR', 3.41, 'False', 'False']
# ['RALYH', 204.89999, 'False', 'False']
# ['RAYSG', 622.0, 'False', 'False']
# ['REEDR', 39.060001, 'False', 'False']
# ['RGYAS', 131.10001, 'False', 'False']
# ['RNPOL', 31.200001, 'False', 'False']
# ['RODRG', 146.0, 'False', 'False']
# ['RPAVS', 5722.0, 'False', 'False']
# ['RPFGY', 4880.0, 'False', 'False']
# ['RTALB', 12.32, 'False', 'False']
# ['RUBNS', 32.84, 'False', 'False']
# ['RYGYO', 43.040001, 'False', 'False']
# ['RYSAS', 50.75, 'False', 'False']
# ['SAFKR', 47.439999, 'False', 'False']
# ['SAHOL', 93.849998, 'False', 'False']
# ['SAMAT', 44.060001, 'False', 'False']
# ['SANEL', 26.24, 'False', 'False']
# ['SANFM', 70.0, 'False', 'False']
# ['SANKO', 24.360001, 'False', 'False']
# ['SARKY', 33.779999, 'False', 'True']
# ['SASA', 44.360001, 'False', 'False']
# ['SAYAS', 66.550003, 'False', 'False']
# ['SDTTR', 283.5, 'False', 'False']
# ['SEGYO', 4.34, 'False', 'False']
# ['SEKFK', 9.81, 'False', 'False']
# ['SEKUR', 12.55, 'False', 'False']
# ['SELEC', 45.259998, 'False', 'False']
# ['SELGD', 42.279999, 'False', 'False']
# ['SELVA', 13.06, 'False', 'False']
# ['SEYKM', 8.54, 'False', 'False']
# ['SILVR', 20.299999, 'False', 'True']
# ['SISE', 48.360001, 'False', 'False']
# ['SKBNK', 3.72, 'True', 'False']
# ['SKTAS', 5.7, 'False', 'False']
# ['SKYLP', 122.0, 'False', 'False']
# ['SKYMD', 13.1, 'False', 'False']
# ['SMART', 36.32, 'False', 'False']
# ['SMRTG', 50.700001, 'False', 'False']
# ['SNGYO', 5.01, 'False', 'False']
# ['SNICA', 7.2, 'False', 'False']
# ['SNKRN', 48.900002, 'False', 'False']
# ['SNPAM', 87.949997, 'False', 'False']
# ['SODSN', 151.2, 'False', 'False']
# ['SOKE', 14.63, 'False', 'False']
# ['SOKM', 64.150002, 'False', 'False']
# ['SONME', 96.699997, 'False', 'True']
# ['SRVGY', 288.0, 'False', 'False']
# ['SUMAS', 425.75, 'False', 'False']
# ['SUNTK', 17.99, 'False', 'False']
# ['SURGY', 48.82, 'False', 'False']
# ['SUWEN', 30.0, 'False', 'False']
# ['TABGD', 183.7, 'False', 'False']
# ['TARKM', 473.5, 'False', 'False']
# ['TATEN', 29.200001, 'False', 'False']
# ['TATGD', 25.92, 'False', 'False']
# ['TAVHL', 244.10001, 'False', 'False']
# ['TBORG', 103.9, 'False', 'False']
# ['TCELL', 98.599998, 'False', 'False']
# ['TDGYO', 11.24, 'False', 'False']
# ['TEKTU', 4.89, 'False', 'False']
# ['TERA', 39.52, 'False', 'False']
# ['TETMT', 8575.0, 'False', 'False']
# ['TEZOL', 18.200001, 'False', 'False']
# ['TGSAS', 65.949997, 'False', 'False']
# ['THYAO', 311.75, 'False', 'False']
# ['TKFEN', 52.75, 'False', 'False']
# ['TKNSA', 34.580002, 'False', 'False']
# ['TLMAN', 114.6, 'False', 'False']
# ['TMPOL', 80.5, 'False', 'False']
# ['TMSN', 138.5, 'False', 'False']
# ['TNZTP', 55.049999, 'False', 'False']
# ['TOASO', 315.5, 'False', 'False']
# ['TRCAS', 27.200001, 'False', 'False']
# ['TRGYO', 47.400002, 'False', 'False']
# ['TRILC', 25.48, 'False', 'False']
# ['TSGYO', 14.01, 'False', 'False']
# ['TSKB', 11.41, 'False', 'False']
# ['TSPOR', 2.14, 'False', 'False']
# ['TTKOM', 48.68, 'False', 'False']
# ['TTRAK', 958.5, 'False', 'True']
# ['TUCLK', 13.33, 'False', 'False']
# ['TUKAS', 7.38, 'False', 'False']
# ['TUPRS', 167.0, 'False', 'False']
# ['TUREX', 62.5, 'False', 'False']
# ['TURGG', 597.5, 'False', 'False']
# ['TURSG', 78.349998, 'False', 'False']
# ['UFUK', 440.0, 'True', 'False']
# ['ULAS', 24.0, 'False', 'False']
# ['ULKER', 155.10001, 'False', 'False']
# ['ULUFA', 13.31, 'True', 'False']
# ['ULUSE', 175.2, 'False', 'False']
# ['ULUUN', 27.84, 'False', 'False']
# ['UMPAS', 11.64, 'False', 'False']
# ['UNLU', 16.5, 'False', 'False']
# ['USAK', 11.15, 'False', 'False']
# ['USDTR', 3076.0, 'False', 'False']
# ['UZERB', 800.5, 'False', 'False']
# ['VAKBN', 23.620001, 'False', 'False']
# ['VAKFN', 3.24, 'False', 'False']
# ['VAKKO', 112.5, 'False', 'False']
# ['VANGD', 19.190001, 'False', 'False']
# ['VBTYZ', 28.52, 'False', 'False']
# ['VERTU', 47.0, 'True', 'False']
# ['VERUS', 263.5, 'False', 'False']
# ['VESBE', 21.34, 'False', 'False']
# ['VESTL', 87.699997, 'False', 'False']
# ['VKFYO', 25.559999, 'False', 'False']
# ['VKGYO', 2.13, 'False', 'False']
# ['VKING', 39.200001, 'False', 'False']
# ['VRGYO', 23.379999, 'False', 'False']
# ['YAPRK', 442.0, 'True', 'False']
# ['YATAS', 37.400002, 'False', 'False']
# ['YAYLA', 16.0, 'False', 'False']
# ['YBTAS', 184042.5, 'False', 'False']
# ['YEOTK', 187.5, 'False', 'False']
# ['YESIL', 4.64, 'False', 'False']
# ['YGGYO', 46.84, 'False', 'False']
# ['YGYO', 10.4, 'False', 'False']
# ['YIGIT', 27.34, 'False', 'False']
# ['YKBNK', 32.580002, 'False', 'False']
# ['YKSLN', 21.459999, 'False', 'False']
# ['YONGA', 77.650002, 'False', 'False']
# ['YUNSA', 81.550003, 'False', 'False']
# ['YYAPI', 6.67, 'False', 'False']
# ['YYLGD', 12.13, 'False', 'False']
# ['Z30EA', 135.2, 'False', 'False']
# ['Z30KE', 103.4, 'False', 'False']
# ['Z30KP', 149.0, 'False', 'False']
# ['ZEDUR', 11.2, 'False', 'False']
# ['ZELOT', 109.25, 'False', 'False']
# ['ZGOLD', 247.0, 'False', 'False']
# ['ZOREN', 5.44, 'False', 'False']
# ['ZPBDL', 156.89999, 'False', 'False']
# ['ZPLIB', 168.3, 'False', 'False']
# ['ZPT10', 82.400002, 'False', 'False']
# ['ZPX30', 148.2, 'False', 'False']
# ['ZRE20', 121.85, 'False', 'False']
# ['ZRGYO', 7.52, 'False', 'False']
# ['ZSR25', 39.529999, 'False', 'False']
# ['ZTM15', 147.3, 'False', 'False']
#     Hisse Adı    Son Fiyat Giriş Sinyali Çıkış Sinyali
# 4       ADGYO    30.000000          True         False
# 56      ASELS    59.349998          True         False
# 176      EKIZ    77.199997          True         False
# 194      ESEN    19.400000          True         False
# 225     GLRYH    11.750000          True         False
# 259     IEYHO     5.060000          True         False
# 272     INVES   333.000000          True         False
# 305      KGYO    35.360001          True         False
# 308     KLKIM    26.780001          True         False
# 351     MACKO    82.550003          True         False
# 371     MIATK    56.500000          True         False
# 372     MIPAZ    80.400002          True         False
# 384     MTRYO     8.970000          True         False
# 415     OZSUB    31.340000          True         False
# 419     PAPIL   135.899990          True         False
# 426     PENGD     7.960000          True         False
# 434     PLTUR    17.059999          True         False
# 441     PRKME    24.080000          True         False
# 447     QPERP  5058.000000          True         False
# 481     SKBNK     3.720000          True         False
# 535      UFUK   440.000000          True         False
# 538     ULUFA    13.310000          True         False
# 551     VERTU    47.000000          True         False
# 559     YAPRK   442.000000          True         False
