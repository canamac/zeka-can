# %% [markdown]
# <a href="https://colab.research.google.com/github/canamac/zeka-can/blob/main/coin_tarama.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import time
import requests
from termcolor import colored
from concurrent.futures import ThreadPoolExecutor, as_completed
from datetime import datetime

def calculate_rsi_wilders(data, column='close', period=14):
    delta = data[column].diff(1)
    gain = delta.where(delta > 0, 0.0)
    loss = -delta.where(delta < 0, 0.0)

    avg_gain = gain.ewm(alpha=1/period, adjust=False).mean()
    avg_loss = loss.ewm(alpha=1/period, adjust=False).mean()

    rs = avg_gain / avg_loss
    return 100.0 - (100.0 / (1.0 + rs))

def get_binance_data(pair):
    try:
        # 1. Veri Çekme
        url = f"https://api.binance.com/api/v3/klines?symbol={pair}&interval=1h&limit=30"
        response = requests.get(url, timeout=20)

        if response.status_code != 200:
            return (pair, None, f"HTTP Error {response.status_code}")

        data = response.json()

        # 2. Veri Kontrolü
        if len(data) < 25:
            return (pair, None, "Yetersiz veri")

        df = pd.DataFrame(data, columns=[
            'timestamp', 'open', 'high', 'low', 'close', 'volume',
            'close_time', 'quote_asset_volume', 'trades',
            'taker_buy_base', 'taker_buy_quote', 'ignore'
        ])

        # 3. Numerik Dönüşüm
        numeric_cols = ['open', 'high', 'low', 'close']
        df[numeric_cols] = df[numeric_cols].apply(pd.to_numeric, errors='coerce')

        # 4. Geçersiz Veri Filtreleme
        if df['close'].isnull().any() or df['high'].isnull().any() or df['low'].isnull().any():
            return (pair, None, "Geçersiz fiyat verisi")

        # 5. Logaritmik Hesaplamalar
        df['logHigh'] = np.log(df['high'].replace(0, np.nan))
        df['logLow'] = np.log(df['low'].replace(0, np.nan))
        df['logClose'] = np.log(df['close'].replace(0, np.nan))

        # 6. RSI Hesaplama
        try:
            df['rsihigh'] = calculate_rsi_wilders(df, 'logHigh')
            df['rsilow'] = calculate_rsi_wilders(df, 'logLow')
            df['rsiclose'] = calculate_rsi_wilders(df, 'logClose')
        except Exception as e:
            return (pair, None, f"RSI hesaplama hatası: {str(e)}")

        # 7. Değişim Oranları
        df['rsiChangeclose'] = df['rsiclose'].diff()
        df['rsiChangelow'] = df['rsilow'].diff()

        # 8. Sinyal Tespiti (Orijinal Mantık)
        signals = []
        for i in range(-5, 0):
            try:
                current_time = datetime.fromtimestamp(df['timestamp'].iloc[i]/1000)
                close_change = df['rsiChangeclose'].iloc[i]
                low_change = df['rsiChangelow'].iloc[i]

                conditions = []
                if close_change > 20:
                    conditions.append(f"{current_time:%H:%M} CLOSE Δ+{close_change:.1f}>20")
                elif close_change > 10:
                    conditions.append(f"{current_time:%H:%M} CLOSE Δ+{close_change:.1f}>10")

                if low_change > 20:
                    conditions.append(f"{current_time:%H:%M} LOW Δ+{low_change:.1f}>20")

                if conditions:
                    signals.append(" | ".join(conditions))

            except Exception:
                continue

        return (pair, df['close'].iloc[-1], signals[-3:] if signals else None)

    except Exception as e:
        return (pair, None, f"Hata: {str(e)}")

if __name__ == "__main__":
    manual_pairs = [
    'BTCUSDT', 'ETHUSDT', 'BNBUSDT', 
    'FDUSDUSDT', 'SEIUSDT', 'CYBERUSDT', 'ARKUSDT', 'CREAMUSDT', 'IQUSDT', 'NTRNUSDT',
    'TIAUSDT', 'MEMEUSDT', 'ORDIUSDT', 'BEAMXUSDT', 'PIVXUSDT', 'VICUSDT', 'BLURUSDT',
    'VANRYUSDT', 'AEURUSDT', 'JTOUSDT', '1000SATSUSDT', 'BONKUSDT', 'ACEUSDT', 'NFPUSDT',
    'AIUSDT', 'XAIUSDT', 'MANTAUSDT', 'ALTUSDT', 'JUPUSDT', 'PYTHUSDT', 'RONINUSDT',
    'DYMUSDT', 'PIXELUSDT', 'STRKUSDT', 'PORTALUSDT', 'PDAUSDT', 'AXLUSDT', 'WIFUSDT',
    'METISUSDT', 'AEVOUSDT', 'BOMEUSDT', 'ETHFIUSDT', 'ENAUSDT', 'WUSDT', 'TNSRUSDT',
    'SAGAUSDT', 'TAOUSDT', 'OMNIUSDT', 'REZUSDT', 'BBUSDT', 'NOTUSDT', 'IOUSDT', 'ZKUSDT',
    'LISTAUSDT', 'ZROUSDT', 'GUSDT', 'BANANAUSDT', 'RENDERUSDT', 'TONUSDT', 'DOGSUSDT',
    'EURIUSDT', 'SLFUSDT', 'POLUSDT', 'NEIROUSDT', 'TURBOUSDT', '1MBABYDOGEUSDT',
    'CATIUSDT', 'HMSTRUSDT', 'EIGENUSDT', 'SCRUSDT', 'BNSOLUSDT', 'LUMIAUSDT', 'KAIAUSDT',
    'COWUSDT', 'CETUSUSDT', 'PNUTUSDT', 'ACTUSDT', 'USUALUSDT', 'THEUSDT', 'ACXUSDT',
    'ORCAUSDT', 'MOVEUSDT', 'MEUSDT', 'VELODROMEUSDT', 'VANAUSDT', '1000CATUSDT',
    'PENGUUSDT', 'BIOUSDT', 'DUSDT', 'AIXBTUSDT', 'CGPTUSDT', 'COOKIEUSDT', 'SUSDT',
    'SOLVUSDT', 'TRUMPUSDT', 'ANIMEUSDT'
]

# Aktif çift filtreleme (BCC, VEN gibi eski çiftleri otomatik temizle)
active_pairs = [p for p in manual_pairs if not any(x in p for x in ['BCC','VEN','BCHABC','BCHSV','USDS','BKRW'])]

start_time = time.time()
print(colored(f"🚀 Toplam {len(active_pairs)} aktif çift taranıyor...", "cyan", attrs=['bold']))

found = []
error_count = 0
processed = 0

with ThreadPoolExecutor(max_workers=3) as executor:
        futures = {executor.submit(get_binance_data, pair): pair for pair in active_pairs}

        for future in as_completed(futures):
            processed += 1
            pair = futures[future]

            # İlerleme çubuğu
            if processed % 5 == 0:
                progress = processed/len(active_pairs)*100
                print(colored(f"▰{'▰'*int(progress//5)}{'▱'*int(20-(progress//5))} {processed}/{len(active_pairs)} ({progress:.1f}%)", "yellow"))

            try:
                result = future.result()
                if result[1] is not None and result[2] is not None:
                    found.append(result)
                elif result[2]:
                    print(colored(f"⚠️ {result[0]}: {result[2]}", "red"))
                    error_count +=1
            except Exception as e:
                print(colored(f"❌ {pair} işlenirken kritik hata: {str(e)}", "red"))
                error_count +=1

            time.sleep(0.3)

    # Sonuçların Gösterimi
print(colored("\n" + "═"*50, "blue"))
print(colored("🔍 SONUÇLAR", "green", attrs=['bold']))
print(colored(f"• Sinyal Bulunan: {len(found)}", "cyan"))
print(colored(f"• Hatalı Çiftler: {error_count}", "red"))
print(colored(f"• Başarı Oranı: {(len(found)/(len(active_pairs)-error_count)*100 if (len(active_pairs)-error_count)!=0 else 0):.1f}%", "yellow"))
print(colored("═"*50 + "\n", "blue"))

if found:
        found.sort(key=lambda x: x[1], reverse=True)

        for coin in found:
            price = colored(f"${coin[1]:,.2f}", "yellow")
            header = colored(f"🎯 {coin[0]:<12}", "magenta") + colored("│ ", "white") + price
            print(header)

            for signal in coin[2]:
                parts = []
                for part in signal.split("|"):
                    if "CLOSE Δ" in part:
                        parts.append(colored(part.strip(), "green"))
                    elif "LOW Δ" in part:
                        parts.append(colored(part.strip(), "cyan"))
                print(colored("   ├─ ", "white") + " | ".join(parts))
            print(colored("   └────────────────────────", "white"))
else:
        print(colored("\n❌ Hiç sinyal bulunamadı", "red", attrs=['bold']))

print(colored(f"\n⏱️ Toplam süre: {time.time()-start_time:.1f} saniye", "yellow", attrs=['bold']))
# Out:
# 🚀 Toplam 394 aktif çift taranıyor...
# ⚠️ BNBUSDT: HTTP Error 451
# ⚠️ ETHUSDT: HTTP Error 451
# ⚠️ BTCUSDT: HTTP Error 451
# ⚠️ NEOUSDT: HTTP Error 451
# ▰▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱ 5/394 (1.3%)
# ⚠️ QTUMUSDT: HTTP Error 451
# ⚠️ LTCUSDT: HTTP Error 451
# ⚠️ ADAUSDT: HTTP Error 451
# ⚠️ XRPUSDT: HTTP Error 451
# ⚠️ EOSUSDT: HTTP Error 451
# ▰▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱ 10/394 (2.5%)
# ⚠️ IOTAUSDT: HTTP Error 451
# ⚠️ TUSDUSDT: HTTP Error 451
# ⚠️ XLMUSDT: HTTP Error 451
# ⚠️ ONTUSDT: HTTP Error 451
# ⚠️ TRXUSDT: HTTP Error 451
# ▰▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱ 15/394 (3.8%)
# ⚠️ ETCUSDT: HTTP Error 451
# ⚠️ ICXUSDT: HTTP Error 451
# ⚠️ NULSUSDT: HTTP Error 451
# ⚠️ VETUSDT: HTTP Error 451
# ⚠️ USDCUSDT: HTTP Error 451
# ▰▰▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱ 20/394 (5.1%)
# ⚠️ LINKUSDT: HTTP Error 451
# ⚠️ ONGUSDT: HTTP Error 451
# ⚠️ ZILUSDT: HTTP Error 451
# ⚠️ HOTUSDT: HTTP Error 451
# ⚠️ ZRXUSDT: HTTP Error 451
# ▰▰▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱ 25/394 (6.3%)
# ⚠️ FETUSDT: HTTP Error 451
# ⚠️ BATUSDT: HTTP Error 451
# ⚠️ ZECUSDT: HTTP Error 451
# ⚠️ CELRUSDT: HTTP Error 451
# ⚠️ IOSTUSDT: HTTP Error 451
# ▰▰▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱ 30/394 (7.6%)
# ⚠️ DASHUSDT: HTTP Error 451
# ⚠️ ENJUSDT: HTTP Error 451
# ⚠️ THETAUSDT: HTTP Error 451
# ⚠️ ATOMUSDT: HTTP Error 451
# ⚠️ TFUELUSDT: HTTP Error 451
# ▰▰▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱ 35/394 (8.9%)
# ⚠️ ONEUSDT: HTTP Error 451
# ⚠️ ALGOUSDT: HTTP Error 451
# ⚠️ DUSKUSDT: HTTP Error 451
# ⚠️ DOGEUSDT: HTTP Error 451
# ⚠️ ANKRUSDT: HTTP Error 451
# ▰▰▰▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱ 40/394 (10.2%)
# ⚠️ WINUSDT: HTTP Error 451
# ⚠️ MTLUSDT: HTTP Error 451
# ⚠️ COSUSDT: HTTP Error 451
# ⚠️ DENTUSDT: HTTP Error 451
# ⚠️ FUNUSDT: HTTP Error 451
# ▰▰▰▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱ 45/394 (11.4%)
# ⚠️ WANUSDT: HTTP Error 451
# ⚠️ CVCUSDT: HTTP Error 451
# ⚠️ BANDUSDT: HTTP Error 451
# ⚠️ CHZUSDT: HTTP Error 451
# ⚠️ XTZUSDT: HTTP Error 451
# ▰▰▰▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱ 50/394 (12.7%)
# ⚠️ HBARUSDT: HTTP Error 451
# ⚠️ RVNUSDT: HTTP Error 451
# ⚠️ NKNUSDT: HTTP Error 451
# ⚠️ KAVAUSDT: HTTP Error 451
# ⚠️ STXUSDT: HTTP Error 451
# ▰▰▰▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱ 55/394 (14.0%)
# ⚠️ ARPAUSDT: HTTP Error 451
# ⚠️ RLCUSDT: HTTP Error 451
# ⚠️ IOTXUSDT: HTTP Error 451
# ⚠️ CTXCUSDT: HTTP Error 451
# ⚠️ TROYUSDT: HTTP Error 451
# ▰▰▰▰▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱ 60/394 (15.2%)
# ⚠️ BCHUSDT: HTTP Error 451
# ⚠️ VITEUSDT: HTTP Error 451
# ⚠️ FTTUSDT: HTTP Error 451
# ⚠️ EURUSDT: HTTP Error 451
# ⚠️ OGNUSDT: HTTP Error 451
# ▰▰▰▰▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱ 65/394 (16.5%)
# ⚠️ LSKUSDT: HTTP Error 451
# ⚠️ BNTUSDT: HTTP Error 451
# ⚠️ LTOUSDT: HTTP Error 451
# ⚠️ COTIUSDT: HTTP Error 451
# ⚠️ MBLUSDT: HTTP Error 451
# ▰▰▰▰▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱ 70/394 (17.8%)
# ⚠️ STPTUSDT: HTTP Error 451
# ⚠️ DATAUSDT: HTTP Error 451
# ⚠️ SOLUSDT: HTTP Error 451
# ⚠️ CTSIUSDT: HTTP Error 451
# ⚠️ HIVEUSDT: HTTP Error 451
# ▰▰▰▰▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱ 75/394 (19.0%)
# ⚠️ CHRUSDT: HTTP Error 451
# ⚠️ ARDRUSDT: HTTP Error 451
# ⚠️ MDTUSDT: HTTP Error 451
# ⚠️ STMXUSDT: HTTP Error 451
# ⚠️ KNCUSDT: HTTP Error 451
# ▰▰▰▰▰▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱ 80/394 (20.3%)
# ⚠️ LRCUSDT: HTTP Error 451
# ⚠️ COMPUSDT: HTTP Error 451
# ⚠️ ZENUSDT: HTTP Error 451
# ⚠️ SNXUSDT: HTTP Error 451
# ⚠️ SCUSDT: HTTP Error 451
# ▰▰▰▰▰▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱ 85/394 (21.6%)
# ⚠️ VTHOUSDT: HTTP Error 451
# ⚠️ SXPUSDT: HTTP Error 451
# ⚠️ DGBUSDT: HTTP Error 451
# ⚠️ MKRUSDT: HTTP Error 451
# ⚠️ STORJUSDT: HTTP Error 451
# ▰▰▰▰▰▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱ 90/394 (22.8%)
# ⚠️ DCRUSDT: HTTP Error 451
# ⚠️ MANAUSDT: HTTP Error 451
# ⚠️ BALUSDT: HTTP Error 451
# ⚠️ YFIUSDT: HTTP Error 451
# ⚠️ KMDUSDT: HTTP Error 451
# ▰▰▰▰▰▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱ 95/394 (24.1%)
# ⚠️ JSTUSDT: HTTP Error 451
# ⚠️ CRVUSDT: HTTP Error 451
# ⚠️ SANDUSDT: HTTP Error 451
# ⚠️ NMRUSDT: HTTP Error 451
# ⚠️ DOTUSDT: HTTP Error 451
# ▰▰▰▰▰▰▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱ 100/394 (25.4%)
# ⚠️ LUNAUSDT: HTTP Error 451
# ⚠️ RSRUSDT: HTTP Error 451
# ⚠️ PAXGUSDT: HTTP Error 451
# ⚠️ TRBUSDT: HTTP Error 451
# ⚠️ SUSHIUSDT: HTTP Error 451
# ▰▰▰▰▰▰▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱ 105/394 (26.6%)
# ⚠️ KSMUSDT: HTTP Error 451
# ⚠️ EGLDUSDT: HTTP Error 451
# ⚠️ DIAUSDT: HTTP Error 451
# ⚠️ RUNEUSDT: HTTP Error 451
# ⚠️ FIOUSDT: HTTP Error 451
# ▰▰▰▰▰▰▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱ 110/394 (27.9%)
# ⚠️ UMAUSDT: HTTP Error 451
# ⚠️ BELUSDT: HTTP Error 451
# ⚠️ WINGUSDT: HTTP Error 451
# ⚠️ UNIUSDT: HTTP Error 451
# ⚠️ OXTUSDT: HTTP Error 451
# ▰▰▰▰▰▰▱▱▱▱▱▱▱▱▱▱▱▱▱▱▱ 115/394 (29.2%)
# ⚠️ SUNUSDT: HTTP Error 451
# ⚠️ AVAXUSDT: HTTP Error 451
# ⚠️ FLMUSDT: HTTP Error 451
# ⚠️ UTKUSDT: HTTP Error 451
# ⚠️ XVSUSDT: HTTP Error 451
# ▰▰▰▰▰▰▰▱▱▱▱▱▱▱▱▱▱▱▱▱▱ 120/394 (30.5%)
# ⚠️ ALPHAUSDT: HTTP Error 451
# ⚠️ AAVEUSDT: HTTP Error 451
# ⚠️ NEARUSDT: HTTP Error 451
# ⚠️ FILUSDT: HTTP Error 451
# ⚠️ INJUSDT: HTTP Error 451
# ▰▰▰▰▰▰▰▱▱▱▱▱▱▱▱▱▱▱▱▱▱ 125/394 (31.7%)
# ⚠️ AUDIOUSDT: HTTP Error 451
# ⚠️ CTKUSDT: HTTP Error 451
# ⚠️ AXSUSDT: HTTP Error 451
# ⚠️ HARDUSDT: HTTP Error 451
# ⚠️ STRAXUSDT: HTTP Error 451
# ▰▰▰▰▰▰▰▱▱▱▱▱▱▱▱▱▱▱▱▱▱ 130/394 (33.0%)
# ⚠️ ROSEUSDT: HTTP Error 451
# ⚠️ AVAUSDT: HTTP Error 451
# ⚠️ SKLUSDT: HTTP Error 451
# ⚠️ GRTUSDT: HTTP Error 451
# ⚠️ JUVUSDT: HTTP Error 451
# ▰▰▰▰▰▰▰▱▱▱▱▱▱▱▱▱▱▱▱▱▱ 135/394 (34.3%)
# ⚠️ PSGUSDT: HTTP Error 451
# ⚠️ 1INCHUSDT: HTTP Error 451
# ⚠️ OGUSDT: HTTP Error 451
# ⚠️ ATMUSDT: HTTP Error 451
# ⚠️ ASRUSDT: HTTP Error 451
# ▰▰▰▰▰▰▰▰▱▱▱▱▱▱▱▱▱▱▱▱▱ 140/394 (35.5%)
# ⚠️ CELOUSDT: HTTP Error 451
# ⚠️ RIFUSDT: HTTP Error 451
# ⚠️ TRUUSDT: HTTP Error 451
# ⚠️ CKBUSDT: HTTP Error 451
# ⚠️ TWTUSDT: HTTP Error 451
# ▰▰▰▰▰▰▰▰▱▱▱▱▱▱▱▱▱▱▱▱▱ 145/394 (36.8%)
# ⚠️ FIROUSDT: HTTP Error 451
# ⚠️ LITUSDT: HTTP Error 451
# ⚠️ SFPUSDT: HTTP Error 451
# ⚠️ DODOUSDT: HTTP Error 451
# ⚠️ CAKEUSDT: HTTP Error 451
# ▰▰▰▰▰▰▰▰▱▱▱▱▱▱▱▱▱▱▱▱▱ 150/394 (38.1%)
# ⚠️ ACMUSDT: HTTP Error 451
# ⚠️ BADGERUSDT: HTTP Error 451
# ⚠️ FISUSDT: HTTP Error 451
# ⚠️ OMUSDT: HTTP Error 451
# ⚠️ DEGOUSDT: HTTP Error 451
# ▰▰▰▰▰▰▰▰▱▱▱▱▱▱▱▱▱▱▱▱▱ 155/394 (39.3%)
# ⚠️ PONDUSDT: HTTP Error 451
# ⚠️ LINAUSDT: HTTP Error 451
# ⚠️ PERPUSDT: HTTP Error 451
# ⚠️ ALICEUSDT: HTTP Error 451
# ⚠️ SUPERUSDT: HTTP Error 451
# ▰▰▰▰▰▰▰▰▰▱▱▱▱▱▱▱▱▱▱▱▱ 160/394 (40.6%)
# ⚠️ TKOUSDT: HTTP Error 451
# ⚠️ CFXUSDT: HTTP Error 451
# ⚠️ BARUSDT: HTTP Error 451
# ⚠️ PUNDIXUSDT: HTTP Error 451
# ⚠️ TLMUSDT: HTTP Error 451
# ▰▰▰▰▰▰▰▰▰▱▱▱▱▱▱▱▱▱▱▱▱ 165/394 (41.9%)
# ⚠️ FORTHUSDT: HTTP Error 451
# ⚠️ BAKEUSDT: HTTP Error 451
# ⚠️ BURGERUSDT: HTTP Error 451
# ⚠️ SLPUSDT: HTTP Error 451
# ⚠️ SHIBUSDT: HTTP Error 451
# ▰▰▰▰▰▰▰▰▰▱▱▱▱▱▱▱▱▱▱▱▱ 170/394 (43.1%)
# ⚠️ ICPUSDT: HTTP Error 451
# ⚠️ ARUSDT: HTTP Error 451
# ⚠️ LPTUSDT: HTTP Error 451
# ⚠️ MASKUSDT: HTTP Error 451
# ⚠️ XVGUSDT: HTTP Error 451
# ▰▰▰▰▰▰▰▰▰▱▱▱▱▱▱▱▱▱▱▱▱ 175/394 (44.4%)
# ⚠️ ATAUSDT: HTTP Error 451
# ⚠️ GTCUSDT: HTTP Error 451
# ⚠️ ERNUSDT: HTTP Error 451
# ⚠️ PHAUSDT: HTTP Error 451
# ⚠️ MLNUSDT: HTTP Error 451
# ▰▰▰▰▰▰▰▰▰▰▱▱▱▱▱▱▱▱▱▱▱ 180/394 (45.7%)
# ⚠️ C98USDT: HTTP Error 451
# ⚠️ DEXEUSDT: HTTP Error 451
# ⚠️ QNTUSDT: HTTP Error 451
# ⚠️ CLVUSDT: HTTP Error 451
# ⚠️ FLOWUSDT: HTTP Error 451
# ▰▰▰▰▰▰▰▰▰▰▱▱▱▱▱▱▱▱▱▱▱ 185/394 (47.0%)
# ⚠️ RAYUSDT: HTTP Error 451
# ⚠️ MINAUSDT: HTTP Error 451
# ⚠️ FARMUSDT: HTTP Error 451
# ⚠️ QUICKUSDT: HTTP Error 451
# ⚠️ MBOXUSDT: HTTP Error 451
# ▰▰▰▰▰▰▰▰▰▰▱▱▱▱▱▱▱▱▱▱▱ 190/394 (48.2%)
# ⚠️ ALPACAUSDT: HTTP Error 451
# ⚠️ GHSTUSDT: HTTP Error 451
# ⚠️ WAXPUSDT: HTTP Error 451
# ⚠️ REQUSDT: HTTP Error 451
# ⚠️ ELFUSDT: HTTP Error 451
# ▰▰▰▰▰▰▰▰▰▰▱▱▱▱▱▱▱▱▱▱▱ 195/394 (49.5%)
# ⚠️ XECUSDT: HTTP Error 451
# ⚠️ GNOUSDT: HTTP Error 451
# ⚠️ DYDXUSDT: HTTP Error 451
# ⚠️ IDEXUSDT: HTTP Error 451
# ⚠️ VIDTUSDT: HTTP Error 451
# ▰▰▰▰▰▰▰▰▰▰▰▱▱▱▱▱▱▱▱▱▱ 200/394 (50.8%)
# ⚠️ USDPUSDT: HTTP Error 451
# ⚠️ GALAUSDT: HTTP Error 451
# ⚠️ ILVUSDT: HTTP Error 451
# ⚠️ YGGUSDT: HTTP Error 451
# ⚠️ SYSUSDT: HTTP Error 451
# ▰▰▰▰▰▰▰▰▰▰▰▱▱▱▱▱▱▱▱▱▱ 205/394 (52.0%)
# ⚠️ DFUSDT: HTTP Error 451
# ⚠️ FIDAUSDT: HTTP Error 451
# ⚠️ AGLDUSDT: HTTP Error 451
# ⚠️ RADUSDT: HTTP Error 451
# ⚠️ BETAUSDT: HTTP Error 451
# ▰▰▰▰▰▰▰▰▰▰▰▱▱▱▱▱▱▱▱▱▱ 210/394 (53.3%)
# ⚠️ RAREUSDT: HTTP Error 451
# ⚠️ LAZIOUSDT: HTTP Error 451
# ⚠️ CHESSUSDT: HTTP Error 451
# ⚠️ ADXUSDT: HTTP Error 451
# ⚠️ AUCTIONUSDT: HTTP Error 451
# ▰▰▰▰▰▰▰▰▰▰▰▱▱▱▱▱▱▱▱▱▱ 215/394 (54.6%)
# ⚠️ BNXUSDT: HTTP Error 451
# ⚠️ MOVRUSDT: HTTP Error 451
# ⚠️ CITYUSDT: HTTP Error 451
# ⚠️ ENSUSDT: HTTP Error 451
# ⚠️ QIUSDT: HTTP Error 451
# ▰▰▰▰▰▰▰▰▰▰▰▰▱▱▱▱▱▱▱▱▱ 220/394 (55.8%)
# ⚠️ POWRUSDT: HTTP Error 451
# ⚠️ PORTOUSDT: HTTP Error 451
# ⚠️ JASMYUSDT: HTTP Error 451
# ⚠️ AMPUSDT: HTTP Error 451
# ⚠️ PYRUSDT: HTTP Error 451
# ▰▰▰▰▰▰▰▰▰▰▰▰▱▱▱▱▱▱▱▱▱ 225/394 (57.1%)
# ⚠️ ALCXUSDT: HTTP Error 451
# ⚠️ SANTOSUSDT: HTTP Error 451
# ⚠️ BICOUSDT: HTTP Error 451
# ⚠️ FLUXUSDT: HTTP Error 451
# ⚠️ FXSUSDT: HTTP Error 451
# ▰▰▰▰▰▰▰▰▰▰▰▰▱▱▱▱▱▱▱▱▱ 230/394 (58.4%)
# ⚠️ HIGHUSDT: HTTP Error 451
# ⚠️ VOXELUSDT: HTTP Error 451
# ⚠️ CVXUSDT: HTTP Error 451
# ⚠️ JOEUSDT: HTTP Error 451
# ⚠️ PEOPLEUSDT: HTTP Error 451
# ▰▰▰▰▰▰▰▰▰▰▰▰▱▱▱▱▱▱▱▱▱ 235/394 (59.6%)
# ⚠️ SPELLUSDT: HTTP Error 451
# ⚠️ ACHUSDT: HTTP Error 451
# ⚠️ IMXUSDT: HTTP Error 451
# ⚠️ GLMRUSDT: HTTP Error 451
# ⚠️ LOKAUSDT: HTTP Error 451
# ▰▰▰▰▰▰▰▰▰▰▰▰▰▱▱▱▱▱▱▱▱ 240/394 (60.9%)
# ⚠️ SCRTUSDT: HTTP Error 451
# ⚠️ API3USDT: HTTP Error 451
# ⚠️ BTTCUSDT: HTTP Error 451
# ⚠️ XNOUSDT: HTTP Error 451
# ⚠️ ACAUSDT: HTTP Error 451
# ▰▰▰▰▰▰▰▰▰▰▰▰▰▱▱▱▱▱▱▱▱ 245/394 (62.2%)
# ⚠️ WOOUSDT: HTTP Error 451
# ⚠️ TUSDT: HTTP Error 451
# ⚠️ ALPINEUSDT: HTTP Error 451
# ⚠️ ASTRUSDT: HTTP Error 451
# ⚠️ KDAUSDT: HTTP Error 451
# ▰▰▰▰▰▰▰▰▰▰▰▰▰▱▱▱▱▱▱▱▱ 250/394 (63.5%)
# ⚠️ GMTUSDT: HTTP Error 451
# ⚠️ APEUSDT: HTTP Error 451
# ⚠️ BIFIUSDT: HTTP Error 451
# ⚠️ BSWUSDT: HTTP Error 451
# ⚠️ NEXOUSDT: HTTP Error 451
# ▰▰▰▰▰▰▰▰▰▰▰▰▰▱▱▱▱▱▱▱▱ 255/394 (64.7%)
# ⚠️ STEEMUSDT: HTTP Error 451
# ⚠️ REIUSDT: HTTP Error 451
# ⚠️ LDOUSDT: HTTP Error 451
# ⚠️ OPUSDT: HTTP Error 451
# ⚠️ LEVERUSDT: HTTP Error 451
# ▰▰▰▰▰▰▰▰▰▰▰▰▰▰▱▱▱▱▱▱▱ 260/394 (66.0%)
# ⚠️ STGUSDT: HTTP Error 451
# ⚠️ GMXUSDT: HTTP Error 451
# ⚠️ LUNCUSDT: HTTP Error 451
# ⚠️ POLYXUSDT: HTTP Error 451
# ⚠️ APTUSDT: HTTP Error 451
