# %% [markdown]
# <a href="https://colab.research.google.com/github/canamac/zeka-can/blob/main/999_HARSI_Gunluk.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
if os.path.exists('StockIndicators.py'):
    os.remove('StockIndicators.py')

# !pip install git+https://github.com/rongardF/tvdatafeed tradingview-screener
# !wget https://raw.githubusercontent.com/Onuragdaci/Stock_Indicators/main/StockIndicators.py

import pandas as pd
import StockIndicators as SI
import numpy as np

exchange = 'BIST'
periyot = '1D'

datas = SI.Stocks(exchange)
print(datas)

Titles = ['Hisse Adı', 'Son Fiyat', 'Giriş Sinyali', 'Çıkış Sinyali']
df_signals = pd.DataFrame(columns=Titles)


for i in range(len(datas)):
    try:
        data = SI.TVGet(datas[i], exchange, periyot, 200)
        O,H,L,C = SI.HARSI(data,14,1)
        data['Entry'] = C > O
        data['Exit'] = O > C
        Buy = False
        Sell = False
        Signals = data.tail(2).reset_index()
        Buy = Signals.loc[0, 'Entry'] == False and Signals.loc[1, 'Entry'] == True
        Sell = Signals.loc[0, 'Exit'] == False and Signals.loc[1, 'Exit'] == True
        Last_Price = Signals.loc[1, 'close']
        L1 = [datas[i], Last_Price, str(Buy), str(Sell)]
        df_signals.loc[len(df_signals)] = L1
        print(L1)
    except Exception as e:
        print(f"Error processing {datas[i]}: {e}")

df_True = df_signals[df_signals['Giriş Sinyali'] == 'True']
print(df_True.to_string())
# Out:
# ...
#   Cloning https://github.com/rongardF/tvdatafeed to /tmp/pip-req-build-4pdq97_k
#   Running command git clone --filter=blob:none --quiet https://github.com/rongardF/tvdatafeed /tmp/pip-req-build-4pdq97_k
#   Resolved https://github.com/rongardF/tvdatafeed to commit e6f6aaa7de439ac6e454d9b26d2760ded8dc4923
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.5/43.5 kB 867.7 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 14.6 MB/s eta 0:00:00
# ...
#   Created wheel for tvdatafeed: filename=tvdatafeed-2.1.0-py3-none-any.whl size=17533 sha256=20473acb5a5081c0a3ad50c2e1e4f575a060a0fdeb5f99011939e19e92413c15
#   Stored in directory: /tmp/pip-ephem-wheel-cache-98giue5u/wheels/e4/32/1e/21ebcacc6549d75fae3bf3ff75cee8fcbe4e5c189d88fbd5a1
# Successfully built tvdatafeed
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.0.3
#     Uninstalling pandas-2.0.3:
#       Successfully uninstalled pandas-2.0.3
# ...
