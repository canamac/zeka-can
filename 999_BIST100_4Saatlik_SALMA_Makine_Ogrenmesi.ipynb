# %% [markdown]
# <a href="https://colab.research.google.com/github/canamac/zeka-can/blob/main/999_BIST100_4Saatlik_SALMA_Makine_Ogrenmesi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
if os.path.exists('StockIndicators.py'):
    os.remove('StockIndicators.py')

# !pip install pandas_ta git+https://github.com/rongardF/tvdatafeed tradingview-screener backtesting
# !wget https://raw.githubusercontent.com/Onuragdaci/Stock_Indicators/main/StockIndicators.py

import StockIndicators as SI
import pandas as pd
import numpy as np
from backtesting import Backtest, Strategy
from tvDatafeed import TvDatafeed, Interval
from tradingview_screener import Query, Column
import warnings
from datetime import datetime
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split, KFold, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn import svm


def model_selection(X, Y):
    seed = 5
    models = [('LR', LogisticRegression()),
        ('LDA', LinearDiscriminantAnalysis()),
        ('KNN', KNeighborsClassifier(n_neighbors=8)),
        ('CART', DecisionTreeClassifier()),
        ('NB', GaussianNB()),
        ('SVM', svm.SVC()),
        ('RFT', RandomForestClassifier())]

    results = []
    names = []
    scoring = 'accuracy'
    for name, model in models:
        kfold = KFold(n_splits=10, shuffle=True, random_state=seed)
        cv_results = cross_val_score(model, X, Y, cv=kfold, scoring=scoring)
        results.append(cv_results)
        names.append(name)

    # Find the best model based on cross-validation accuracy
    best_model_index = np.argmax(np.mean(results, axis=1))
    best_model_name = names[best_model_index]
    best_model = models[best_model_index][1]
    return best_model

class Strategy(Strategy):
    def init(self):
        pass
    def next(self):
        if self.data['Entry'] == True and not self.position:
            self.buy()

        elif self.data['Exit'] == True:
            self.position.close()

Hisseler = [
    "AEFES", "AGROT", "AHGAZ", "AKBNK", "AKCNS", "AKFGY", "AKFYE", "AKSA", "AKSEN",
    "ALARK", "ALBRK", "ALFAS", "ANSGR", "ARCLK", "ASELS", "ASTOR", "BERA", "BFREN",
    "BIENY", "BIMAS", "BIOEN", "BOBET", "BRSAN", "BRYAT", "BTCIM", "CANTE", "CCOLA",
    "CIMSA", "CWENE", "DOAS", "DOHOL", "ECILC", "ECZYT", "EGEEN", "EKGYO", "ENERY",
    "ENJSA", "ENKAI", "EREGL", "EUPWR", "EUREN", "FROTO", "GARAN", "GESAN", "GUBRF",
    "GWIND", "HALKB", "HEKTS", "IPEKE", "ISCTR", "ISGYO", "ISMEN", "IZENR", "KAYSE",
    "KCAER", "KCHOL", "KLSER", "KONTR", "KONYA", "KOZAA", "KOZAL", "KRDMD", "MAVI",
    "MGROS", "MIATK", "ODAS", "OTKAR", "OYAKC", "PETKM", "PGSUS", "QUAGR", "REEDR",
    "SAHOL", "SASA", "SAYAS", "SDTTR", "SISE", "SKBNK", "SMRTG", "SOKM", "TABGD",
    "TAVHL", "TCELL", "THYAO", "TKFEN", "TOASO", "TSKB", "TTKOM", "TTRAK", "TUKAS",
    "TUPRS", "TURSG", "ULKER", "VAKBN", "VESBE", "VESTL", "YEOTK", "YKBNK", "YYLGD",
    "ZOREN"]


#Raporlama için kullanılacak başlıklar
Titles = ['Hisse Adı', 'Son Fiyat', 'Algo Öncesi Kazanma Oranı','Algo Öncesi Giriş Sinyali', 'Algo Öncesi Çıkış Sinyali','Algo Sonrası Kazanma Oranı', 'Algo Sonrası Giriş Sinyali', 'Algo Öncesi Çıkış Sinyali']
df_signals = pd.DataFrame(columns=Titles)

for i in range(0,len(Hisseler)):
    try:
        data = SI.TVGet(Hisseler[i], 'BIST', '4h', 1000)
        """İndikatörlerin Hesaplanması"""
        data['RSI'] = SI.rsi(data['close'], 14)
        data['OBV'] = SI.obv(data['close'], data['volume'])
        data['MOM'] = SI.momentum(data['close'], 14)
        data['SALMA'] = SI.salma(data['close'])

        """Giriş ve Çıkış Koşullarının Belirlenmesi"""
        data['Entry'] = (data['SALMA'] > data['SALMA'].shift(1)).astype(int)
        data['Exit'] = (data['Entry'] == 0).astype(int)

        """Öğrenme Algoritmasında Kullanılacak Unsurlar ve Hedefin Tanımlanması"""
        features = ['RSI', 'OBV','MOM']
        target = 'Entry'

        """Varsa Verideki NaN Değerlerinin Silinmesi"""
        data = data.dropna().reset_index(drop=True)

        """Makine Öğrenmesinde Kullanılacak X ve y nin tanımlanması"""
        X = data[features]
        y = data[target]

        """ Standart Scaler ' ın çağırılması ve Verilerin Scale edilmesi"""
        scaler = StandardScaler()
        X_scaled = scaler.fit_transform(X)


        """ En uygun Modelin bulunması"""
        best_model = model_selection(X_scaled, y)

        """ Verilerin En uygun modele göre fit edilmesi"""
        X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)
        best_model.fit(X_train, y_train)

        """Sonuçların Karışlaştırılması için test kümesinde teni bir dataframe oluşturulması"""
        df_X_test = pd.DataFrame()
        df_X_test['datetime'] = data.loc[:len(X_test)-1, 'datetime']
        df_X_test['Open'] = data.loc[:len(X_test)-1, 'open']
        df_X_test['High'] = data.loc[:len(X_test)-1, 'high']
        df_X_test['Low'] = data.loc[:len(X_test)-1, 'low']
        df_X_test['Close'] = data.loc[:len(X_test)-1, 'close']
        df_X_test['Volume'] = data.loc[:len(X_test)-1, 'volume']
        df_X_test['Entry'] = data.loc[:len(X_test)-1, 'Entry']
        df_X_test['Exit'] = data.loc[:len(X_test)-1, 'Exit']
        df_test = df_X_test.copy()

        """Algoritma Öncesi Backtest Sonuçları ve Kazanma Oranı"""
        df_test['datetime'] = pd.to_datetime(df_X_test['datetime'])
        df_test.set_index('datetime', inplace=True)
        bt = Backtest(df_test, Strategy, cash=100000, commission=0.002)
        Stats= bt.run()
        Buy_1 = False
        Sell_1 = False
        Signals = df_test.tail(2)
        Signals = Signals.reset_index()
        Buy1 = Signals.loc[0, 'Entry'] == False and Signals.loc[1, 'Entry'] == True
        Sell1 = Signals.loc[0, 'Exit'] == False and Signals.loc[1, 'Exit'] == True
        WR1 = round(Stats.loc['Win Rate [%]'], 2)

        """Algoritma Sonrası Backtest Sonuçları ve Kazanma Oranı"""
        df_test['Entry'] = best_model.predict(X_test)
        df_test['Exit']  = (df_test['Entry'] == 0).astype(int)
        bt = Backtest(df_test, Strategy, cash=100000, commission=0.002)
        Stats= bt.run()
        Signals = df_test.tail(2)
        Signals = Signals.reset_index()
        Buy2 = Signals.loc[0, 'Entry'] == False and Signals.loc[1, 'Entry'] == True
        Sell2 = Signals.loc[0, 'Exit'] == False and Signals.loc[1, 'Exit'] == True
        WR2 = round(Stats.loc['Win Rate [%]'], 2)

        """Sonuçların Liste Halinde birleştirilmesi"""
        Last_Price = Signals.loc[1, 'Close']
        L1 = [Hisseler[i],Last_Price, WR1, str(Buy1), str(Sell1),WR2, str(Buy2), str(Sell2)]
        df_signals.loc[len(df_signals)] = L1
        print(L1)
    except:
        pass

"""Algoritma Sonrası Sonuçların Önceki Sonuçtan Daha iyi olduğu ve Giriş Sinyali'nin oluştuğu verilerin filtrelenmesi """
df_True = df_signals[(df_signals['Algo Sonrası Kazanma Oranı'] > df_signals['Algo Öncesi Kazanma Oranı']) &
                     (df_signals['Algo Sonrası Giriş Sinyali'] == 'True')]

"""Sonuçların Basılması """
print(df_True.to_string())
# Out:
# Collecting git+https://github.com/rongardF/tvdatafeed
#   Cloning https://github.com/rongardF/tvdatafeed to /tmp/pip-req-build-lpnswr1e
#   Running command git clone --filter=blob:none --quiet https://github.com/rongardF/tvdatafeed /tmp/pip-req-build-lpnswr1e
#   Resolved https://github.com/rongardF/tvdatafeed to commit e6f6aaa7de439ac6e454d9b26d2760ded8dc4923
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas_ta in /usr/local/lib/python3.10/dist-packages (0.3.14b0)
# Requirement already satisfied: tradingview-screener in /usr/local/lib/python3.10/dist-packages (2.5.0)
# Requirement already satisfied: backtesting in /usr/local/lib/python3.10/dist-packages (0.3.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from pandas_ta) (2.2.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tvdatafeed==2.1.0) (67.7.2)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from tvdatafeed==2.1.0) (1.8.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from tvdatafeed==2.1.0) (2.31.0)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from backtesting) (1.25.2)
# Requirement already satisfied: bokeh>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from backtesting) (3.3.4)
# Requirement already satisfied: Jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from bokeh>=1.4.0->backtesting) (3.1.4)
# Requirement already satisfied: contourpy>=1 in /usr/local/lib/python3.10/dist-packages (from bokeh>=1.4.0->backtesting) (1.2.1)
# Requirement already satisfied: packaging>=16.8 in /usr/local/lib/python3.10/dist-packages (from bokeh>=1.4.0->backtesting) (24.1)
# Requirement already satisfied: pillow>=7.1.0 in /usr/local/lib/python3.10/dist-packages (from bokeh>=1.4.0->backtesting) (9.4.0)
# Requirement already satisfied: PyYAML>=3.10 in /usr/local/lib/python3.10/dist-packages (from bokeh>=1.4.0->backtesting) (6.0.1)
# Requirement already satisfied: tornado>=5.1 in /usr/local/lib/python3.10/dist-packages (from bokeh>=1.4.0->backtesting) (6.3.3)
# Requirement already satisfied: xyzservices>=2021.09.1 in /usr/local/lib/python3.10/dist-packages (from bokeh>=1.4.0->backtesting) (2024.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->pandas_ta) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pandas_ta) (2023.4)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->pandas_ta) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->tvdatafeed==2.1.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->tvdatafeed==2.1.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->tvdatafeed==2.1.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->tvdatafeed==2.1.0) (2024.6.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=2.9->bokeh>=1.4.0->backtesting) (2.1.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->pandas_ta) (1.16.0)
# --2024-06-23 01:06:09--  https://raw.githubusercontent.com/Onuragdaci/Stock_Indicators/main/StockIndicators.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 50131 (49K) [text/plain]
# Saving to: ‘StockIndicators.py’
#
# StockIndicators.py  100%[===================>]  48.96K  --.-KB/s    in 0.007s
#
# 2024-06-23 01:06:09 (7.30 MB/s) - ‘StockIndicators.py’ saved [50131/50131]
#
# ['AEFES', 58.2, 33.33, 'False', 'True', 46.15, 'False', 'True']
# ['AGROT', 14.5, 50.0, 'False', 'False', 66.67, 'False', 'False']
# ['AHGAZ', 7.52, 25.0, 'False', 'False', 41.67, 'False', 'True']
# ['AKBNK', 15.8, 41.67, 'False', 'False', 40.82, 'False', 'True']
# ['AKCNS', 74.95, 57.14, 'False', 'False', 42.31, 'False', 'True']
# ['AKFGY', 1.752756, 55.56, 'False', 'False', 41.51, 'False', 'True']
# ['AKFYE', 9.71, 40.0, 'False', 'False', 45.65, 'False', 'False']
# ['AKSA', 63.85, 22.22, 'False', 'False', 31.91, 'False', 'False']
# ['AKSEN', 34.04, 33.33, 'False', 'False', 42.31, 'False', 'True']
# ['ALARK', 67.75, 42.86, 'False', 'False', 37.04, 'False', 'True']
# ['ALBRK', 2.5, 33.33, 'False', 'False', 45.24, 'False', 'True']
# ['ALFAS', 40.7, 62.5, 'False', 'False', 53.49, 'False', 'True']
# ['ANSGR', 17.75, 36.36, 'False', 'False', 47.92, 'False', 'True']
# ['ARCLK', 96.3, 22.22, 'False', 'False', 32.65, 'False', 'True']
# ['ASELS', 23.75, 28.57, 'False', 'False', 47.92, 'False', 'False']
# ['ASTOR', 52.5, 50.0, 'False', 'False', 49.02, 'False', 'True']
# ['BERA', 10.06, 37.5, 'False', 'False', 39.53, 'False', 'True']
# ['BFREN', 304.779735, 33.33, 'False', 'False', 39.13, 'False', 'True']
# ['BIENY', 67.5, 66.67, 'False', 'False', 43.24, 'True', 'False']
# ['BIMAS', 141.0, 37.5, 'False', 'False', 54.76, 'False', 'True']
# ['BIOEN', 14.17, 28.57, 'False', 'False', 47.92, 'False', 'False']
# ['BOBET', 20.04, 42.86, 'False', 'False', 35.85, 'False', 'True']
# ['BRSAN', 181.0, 83.33, 'True', 'False', 55.77, 'False', 'False']
# ['BRYAT', 900.0, 44.44, 'False', 'False', 42.86, 'False', 'True']
# ['BTCIM', 36.92, 28.57, 'False', 'False', 39.22, 'True', 'False']
# ['CANTE', 21.52, 10.0, 'False', 'False', 31.82, 'False', 'True']
# ['CCOLA', 231.3, 27.27, 'False', 'False', 48.65, 'False', 'False']
# ['CIMSA', 15.442842, 25.0, 'False', 'False', 42.11, 'False', 'False']
# ['CWENE', 345.2, 83.33, 'False', 'False', 55.56, 'False', 'False']
# ['DOAS', 142.9, 22.22, 'False', 'False', 37.04, 'False', 'True']
# ['DOHOL', 8.33, 27.27, 'False', 'False', 45.65, 'False', 'False']
# ['ECILC', 27.68, 37.5, 'False', 'False', 49.06, 'False', 'True']
# ['ECZYT', 132.2, 50.0, 'False', 'False', 52.94, 'False', 'True']
# ['EGEEN', 4657.2, 22.22, 'False', 'False', 40.0, 'False', 'True']
# ['EKGYO', 7.11, 37.5, 'False', 'False', 28.57, 'False', 'True']
# ['ENERY', 140.2, 33.33, 'False', 'False', 26.92, 'False', 'True']
# ['ENJSA', 31.0, 12.5, 'False', 'False', 41.3, 'False', 'True']
# ['ENKAI', 25.86, 40.0, 'False', 'False', 42.22, 'False', 'True']
# ['EREGL', 33.04, 14.29, 'False', 'False', 27.45, 'False', 'True']
# ['EUPWR', 173.1, 57.14, 'False', 'False', 61.9, 'True', 'False']
# ['EUREN', 9.09, 25.0, 'False', 'False', 38.64, 'False', 'True']
# ['FROTO', 573.2, 18.18, 'False', 'False', 40.38, 'False', 'True']
# ['GARAN', 26.78, 30.0, 'False', 'False', 50.0, 'False', 'True']
# ['GESAN', 59.9, 40.0, 'False', 'False', 37.5, 'False', 'True']
# ['GUBRF', 259.0, 40.0, 'False', 'False', 56.0, 'False', 'False']
# ['GWIND', 17.321291, 33.33, 'False', 'False', 40.0, 'False', 'True']
# ['HALKB', 12.67, 50.0, 'False', 'False', 36.73, 'False', 'False']
# ['HEKTS', 27.86, 37.5, 'False', 'False', 40.48, 'False', 'True']
# ['IPEKE', 27.44, 33.33, 'False', 'False', 37.74, 'False', 'True']
# ['ISCTR', 4.64, 50.0, 'False', 'False', 46.94, 'False', 'True']
# ['ISGYO', 8.9, 50.0, 'False', 'False', 42.55, 'False', 'False']
# ['ISMEN', 11.464149, 33.33, 'False', 'False', 44.68, 'False', 'True']
# ['IZENR', 35.62, 100.0, 'False', 'False', 37.04, 'False', 'False']
# ['KAYSE', 34.7, 83.33, 'False', 'False', 47.73, 'True', 'False']
# ['KCAER', 16.28, 22.22, 'False', 'False', 38.89, 'False', 'True']
# ['KCHOL', 78.8, 33.33, 'False', 'False', 48.94, 'False', 'True']
# ['KLSER', 93.5, 60.0, 'False', 'False', 44.83, 'True', 'False']
# ['KONTR', 143.0, 30.0, 'False', 'False', 48.0, 'False', 'True']
# ['KONYA', 3258.2, 37.5, 'False', 'False', 37.25, 'False', 'True']
# ['KOZAA', 45.1, 42.86, 'False', 'False', 32.69, 'False', 'True']
# ['KOZAL', 23.02, 33.33, 'False', 'False', 37.04, 'False', 'True']
# ['KRDMD', 17.57, 25.0, 'False', 'False', 40.38, 'False', 'True']
# ['MAVI', 27.0, 27.27, 'False', 'False', 53.19, 'False', 'True']
# ['MGROS', 172.5, 36.36, 'False', 'False', 50.0, 'False', 'True']
# ['MIATK', 8.1923, 41.67, 'False', 'False', 36.96, 'False', 'False']
# ['ODAS', 6.62, 75.0, 'False', 'False', 30.61, 'False', 'True']
# ['OTKAR', 167.0, 42.86, 'False', 'False', 36.96, 'False', 'True']
# ['OYAKC', 41.34, 50.0, 'False', 'False', 37.74, 'False', 'True']
# ['PETKM', 13.99, 10.0, 'False', 'False', 40.38, 'False', 'False']
# ['PGSUS', 93.8700212, 33.33, 'False', 'False', 49.06, 'False', 'True']
# ['QUAGR', 7.63636282, 62.5, 'False', 'False', 67.39, 'False', 'False']
# ['REEDR', 30.24, 75.0, 'False', 'False', 60.0, 'True', 'False']
# ['SAHOL', 38.6, 50.0, 'False', 'False', 30.0, 'False', 'True']
# ['SASA', 54.0, 22.22, 'False', 'False', 48.98, 'False', 'False']
# ['SAYAS', 24.44, 11.11, 'False', 'False', 42.0, 'False', 'True']
# ['SDTTR', 122.5, 33.33, 'False', 'False', 42.22, 'False', 'True']
# ['SISE', 40.36, 18.18, 'False', 'False', 36.73, 'False', 'True']
# ['SKBNK', 1.90641551, 37.5, 'False', 'False', 42.86, 'False', 'True']
# ['SMRTG', 38.661578, 57.14, 'False', 'False', 33.33, 'False', 'True']
# ['SOKM', 27.2, 55.56, 'False', 'False', 46.0, 'False', 'True']
# ['TABGD', 130.8, 33.33, 'False', 'False', 21.43, 'True', 'False']
# ['TAVHL', 77.65, 37.5, 'False', 'False', 45.83, 'False', 'True']
# ['TCELL', 33.5, 44.44, 'False', 'False', 40.43, 'False', 'True']
# ['THYAO', 143.8, 18.18, 'False', 'False', 36.17, 'False', 'True']
# ['TKFEN', 29.8, 42.86, 'False', 'False', 50.98, 'False', 'True']
# ['TOASO', 214.5, 44.44, 'False', 'False', 47.17, 'False', 'True']
# ['TSKB', 4.1, 55.56, 'False', 'False', 46.0, 'False', 'True']
# ['TTKOM', 16.03, 50.0, 'False', 'False', 37.5, 'False', 'False']
# ['TTRAK', 352.746446, 42.86, 'False', 'False', 47.06, 'False', 'True']
# ['TUKAS', 4.659995, 66.67, 'False', 'False', 44.9, 'False', 'True']
# ['TUPRS', 67.0, 18.18, 'False', 'False', 44.68, 'False', 'True']
# ['TURSG', 11.17, 44.44, 'False', 'False', 44.44, 'False', 'True']
# ['ULKER', 33.8, 55.56, 'False', 'False', 53.7, 'False', 'False']
# ['VAKBN', 9.38, 71.43, 'False', 'False', 32.65, 'False', 'False']
# ['VESBE', 10.98, 28.57, 'False', 'False', 35.42, 'False', 'True']
# ['VESTL', 44.92, 33.33, 'False', 'False', 40.0, 'False', 'True']
# ['YEOTK', 64.0, 62.5, 'False', 'False', 48.89, 'False', 'True']
# ['YKBNK', 10.2, 55.56, 'False', 'False', 53.19, 'False', 'True']
# ['YYLGD', 10.347812, 42.86, 'False', 'False', 26.09, 'False', 'False']
# ['ZOREN', 2.985041, 66.67, 'False', 'False', 43.75, 'False', 'True']
#    Hisse Adı  Son Fiyat  Algo Öncesi Kazanma Oranı Algo Öncesi Giriş Sinyali Algo Öncesi Çıkış Sinyali  Algo Sonrası Kazanma Oranı Algo Sonrası Giriş Sinyali Algo Öncesi Çıkış Sinyali
# 24     BTCIM      36.92                      28.57                     False                     False                       39.22                       True                     False
# 39     EUPWR     173.10                      57.14                     False                     False                       61.90                       True                     False
