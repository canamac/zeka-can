# %% [markdown]
# <a href="https://colab.research.google.com/github/canamac/zeka-can/blob/main/10_Finans_i%C3%A7in_Python_BIST100_Ritmi_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/rongardF/tvdatafeed
import pandas as pd
from tvDatafeed import TvDatafeed, Interval

tv = TvDatafeed()

# Hisse isimlerinin tanımlanması
bist100 = [
    "AEFES", "AGHOL", "AGROT", "AKBNK", "AKFGY", "AKFYE", "AKSA", "AKSEN", "ALARK", "ALFAS",
    "ARCLK", "ARDYZ", "ASELS", "ASTOR", "BERA", "BFREN", "BIMAS", "BINHO", "BRSAN", "BRYAT",
    "BTCIM", "CANTE", "CCOLA", "CIMSA", "CWENE", "DOAS", "DOHOL", "ECILC", "ECZYT", "EGEEN",
    "EKGYO", "ENERY", "ENJSA", "ENKAI", "EREGL", "EUPWR", "EUREN", "FROTO", "GARAN", "GESAN",
    "GOLTS", "GUBRF", "HALKB", "HEKTS", "ISCTR", "ISGYO", "ISMEN", "IZENR", "KAYSE", "KCAER",
    "KCHOL", "KLSER", "KONTR", "KONYA", "KOZAA", "KOZAL", "KRDMD", "KTLEV", "LMKDC", "MAVI",
    "MGROS", "MIATK", "OBAMS", "ODAS", "OTKAR", "OYAKC", "PEKGY", "PETKM", "PGSUS", "QUAGR",
    "REEDR", "SAHOL", "SASA", "SDTTR", "SISE", "SKBNK", "SMRTG", "SOKM", "TABGD", "TAVHL",
    "TCELL", "THYAO", "TKFEN", "TKNSA", "TMSN", "TOASO", "TSKB", "TTKOM", "TTRAK", "TUKAS",
    "TUPRS", "TURSG", "ULKER", "VAKBN", "VESBE", "VESTL", "YEOTK", "YKBNK", "YYLGD", "ZOREN"
]

# Sonuçları saklamak için boş bir DataFrame oluştur
sonuclar = pd.DataFrame(columns=['Hisse', 'En_Iyi_Alim_Gunu', 'En_Iyi_Satim_Gunu'])

for hisse in bist100:
    try:
        # Günlük veri çekme
        veri = tv.get_hist(symbol=hisse, exchange='BIST', interval=Interval.in_daily, n_bars=5000)

        if veri.empty:
            print(f"{hisse} için veri yok")
            continue

        # Ay ve günü ekleme
        veri['Ay'] = veri.index.month
        veri['Ayin_Gunu'] = veri.index.day

        # Her ay için fiyatları 0-1 arasında ölçekleme
        veri['Olcekli_Dusuk'] = veri.groupby('Ay')['low'].transform(lambda x: (x - x.min()) / (x.max() - x.min()))
        veri['Olcekli_Yuksek'] = veri.groupby('Ay')['high'].transform(lambda x: (x - x.min()) / (x.max() - x.min()))

        # Her ayın günü için ortalama değerleri hesaplama
        gunluk_analiz = veri.groupby('Ayin_Gunu').agg({
            'Olcekli_Dusuk': 'mean',
            'Olcekli_Yuksek': 'mean'
        }).rename(columns={
            'Olcekli_Dusuk': 'Ort_Olcekli_Dusuk',
            'Olcekli_Yuksek': 'Ort_Olcekli_Yuksek'
        })

        # En iyi alım ve satım günlerini bulma
        en_iyi_alim_gunu = gunluk_analiz['Ort_Olcekli_Dusuk'].idxmin()
        en_iyi_satim_gunu = gunluk_analiz['Ort_Olcekli_Yuksek'].idxmax()

        # Sonuçları DataFrame'e ekle
        sonuclar = pd.concat([sonuclar, pd.DataFrame({
            'Hisse': [hisse],
            'En_Iyi_Alim_Gunu': [en_iyi_alim_gunu],
            'En_Iyi_Satim_Gunu': [en_iyi_satim_gunu]
        })], ignore_index=True)

    except Exception as e:
        print(f"{hisse} için hata: {e}")

# Sonuçları göster
print(sonuclar.to_string(index=False))
# Out:
# Collecting git+https://github.com/rongardF/tvdatafeed
#   Cloning https://github.com/rongardF/tvdatafeed to /tmp/pip-req-build-xx0jw26f
#   Running command git clone --filter=blob:none --quiet https://github.com/rongardF/tvdatafeed /tmp/pip-req-build-xx0jw26f
#   Resolved https://github.com/rongardF/tvdatafeed to commit e6f6aaa7de439ac6e454d9b26d2760ded8dc4923
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tvdatafeed==2.1.0) (71.0.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from tvdatafeed==2.1.0) (2.1.4)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from tvdatafeed==2.1.0) (1.8.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from tvdatafeed==2.1.0) (2.31.0)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas->tvdatafeed==2.1.0) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->tvdatafeed==2.1.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->tvdatafeed==2.1.0) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->tvdatafeed==2.1.0) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->tvdatafeed==2.1.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->tvdatafeed==2.1.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->tvdatafeed==2.1.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->tvdatafeed==2.1.0) (2024.7.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->tvdatafeed==2.1.0) (1.16.0)
# Building wheels for collected packages: tvdatafeed
#   Building wheel for tvdatafeed (setup.py) ... done
#   Created wheel for tvdatafeed: filename=tvdatafeed-2.1.0-py3-none-any.whl size=17532 sha256=3404a91cf45e5c5b2d47910d53c6fe3465c3c0d56c62cafe52e48ef7eb22ccd4
#   Stored in directory: /tmp/pip-ephem-wheel-cache-sjt_e7zx/wheels/e4/32/1e/21ebcacc6549d75fae3bf3ff75cee8fcbe4e5c189d88fbd5a1
# Successfully built tvdatafeed
# Installing collected packages: tvdatafeed
# Successfully installed tvdatafeed-2.1.0
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# Hisse En_Iyi_Alim_Gunu En_Iyi_Satim_Gunu
# AEFES               10                29
# AGHOL               10                29
# AGROT                5                14
# AKBNK               10                29
# AKFGY               30                 1
# AKFYE                2                29
#  AKSA               11                29
# AKSEN               30                29
# ALARK               10                29
# ALFAS               23                15
# ARCLK               11                29
# ARDYZ               10                29
# ASELS               10                29
# ASTOR               20                31
#  BERA               13                29
# BFREN               10                29
# BIMAS               10                29
# BINHO                2                 6
# BRSAN               10                29
# BRYAT               30                29
# BTCIM               10                29
# CANTE               11                26
# CCOLA               30                29
# CIMSA               10                29
# CWENE               19                 6
#  DOAS               10                29
# DOHOL               10                29
# ECILC               10                29
# ECZYT               10                29
# EGEEN               10                29
# EKGYO               10                29
# ENERY               14                21
# ENJSA               10                29
# ENKAI               11                29
# EREGL               11                29
# EUPWR               23                 7
# EUREN               27                25
# FROTO               10                29
# GARAN               10                29
# GESAN                1                12
# GOLTS               30                29
# GUBRF               30                31
# HALKB               30                 5
# HEKTS               30                31
# ISCTR               10                29
# ISGYO               10                29
# ISMEN               10                29
# IZENR               27                 6
# KAYSE               26                12
# KCAER                7                29
# KCHOL               10                29
# KLSER               27                 6
# KONTR                1                29
# KONYA               10                29
# KOZAA               10                29
# KOZAL               11                29
# KRDMD               30                29
# KTLEV               15                30
# LMKDC               12                 6
#  MAVI               10                29
# MGROS               10                29
# MIATK                7                29
# OBAMS               29                15
#  ODAS               10                29
# OTKAR               10                29
# OYAKC               10                29
# PEKGY               30                29
# PETKM               10                29
# PGSUS               10                29
# QUAGR                1                 6
# REEDR                2                11
# SAHOL               10                29
#  SASA               10                31
# SDTTR               27                 8
#  SISE               11                29
# SKBNK               30                31
# SMRTG               30                 2
#  SOKM               10                29
# TABGD                3                 1
# TAVHL               10                29
# TCELL               10                29
# THYAO               10                29
# TKFEN               30                22
# TKNSA               10                29
#  TMSN               10                29
# TOASO               30                29
#  TSKB               10                29
# TTKOM               10                29
# TTRAK               10                29
# TUKAS               11                29
# TUPRS               10                29
# TURSG               10                29
# ULKER               14                29
# VAKBN               10                19
# VESBE               11                29
# VESTL               11                29
# YEOTK                7                29
# YKBNK               10                29
# YYLGD                3                24
# ZOREN               10                29
